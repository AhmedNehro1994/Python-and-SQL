# %% [markdown]
# ##
# This is a project based on Python to connect and read the database of books called base to answer some questions

# %%
import sqlite3
db =sqlite3.connect('base.db')
cr= db.cursor()
db.commit()

# %% [markdown]
# ## Answer these questions

# %%
ques1= cr.execute("SELECT bookname from book1000 WHERE bookname like '%Mr%' and rate >= 3")
ques1.fetchall()
# Out:
# [('Mrs. Houdini',), ('My Mrs. Brown',), ('Dear Mr. Knightley',)]

# %%
ques2= cr.execute("SELECT bookname from book1000 WHERE price >20 and rate >= 3")
ques2.fetchall()
# Out:
# [('A Light in the Attic',),
#  ('Sharp Objects',),
#  ('Sapiens: A Brief History of Humankind',),
#  ('The Dirty Little Secrets of Getting Your Dream Job',),
#  ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',),
#  ("Shakespeare's Sonnets",),
#  ("Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",),
#  ('Rip it Up and Start Again',),
#  ('Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',),
#  ('Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',),
#  ('Chase Me (Paris Nights #2)',),
#  ('Black Dust',),
#  ('Birdsong: A Story in Pictures',),
#  ("America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",),
#  ('Aladdin and His Wonderful Lamp',),
#  ('Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe',),
#  ('Wall and Piece',),
#  ('The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',),
#  ('The Elephant Tree',),
#  ('Penny Maybe',),
#  ('Behind Closed Doors',),
#  ('Slow States of Collapse: Poems',),
#  ('Private Paris (Private #10)',),
#  ('#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',),
#  ('We Love You, Charlie Freeman',),
#  ('Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',),
#  ('Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',),
#  ('The Past Never Ends',),
#  ('The Natural History of Us (The Fine Art of Pretending #2)',),
#  ('The Nameless City (The Nameless City #1)',),
#  ('The Murder That Never Was (Forensic Instincts #5)',),
#  ("The Most Perfect Thing: Inside (and Outside) a Bird's Egg",),
#  ('The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',),
#  ('The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',),
#  ('The Death of Humanity: and the Case for Life',),
#  ('The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',),
#  ('The Art Forger',),
#  ("The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",),
#  ('Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',),
#  ('Saga, Volume 6 (Saga (Collected Editions) #6)',),
#  ('Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',),
#  ('Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',),
#  ('Join',),
#  ('In the Country We Love: My Family Divided',),
#  ('Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',),
#  ('I am a Hero Omnibus Volume 1',),
#  ('Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',),
#  ('Danganronpa Volume 1',),
#  ('Crown of Midnight (Throne of Glass #2)',),
#  ('Codename Baboushka, Volume 1: The Conclave of Death',),
#  ('Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',),
#  ('Burning',),
#  ('A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',),
#  ('A Flight of Arrows (The Pathfinders #2)',),
#  ('A Fierce and Subtle Poison',),
#  ('(Un)Qualified: How God Uses Broken People to Do Big Things',),
#  ('You Are What You Love: The Spiritual Power of Habit',),
#  ("William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",),
#  ('Tracing Numbers on a Train',),
#  ('Throne of Glass (Throne of Glass #1)',),
#  ('The White Cat and the Monk: A Retelling of the Poem â\x80\x9cPangur BÃ¡nâ\x80\x9d',),
#  ('The Vacationers',),
#  ('The Secret (The Secret #1)',),
#  ('The Regional Office Is Under Attack!',),
#  ('The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',),
#  ('The Murder of Roger Ackroyd (Hercule Poirot #4)',),
#  ('The Mistake (Off-Campus #2)',),
#  ('The Kite Runner',),
#  ("The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",),
#  ("The Artist's Way: A Spiritual Path to Higher Creativity",),
#  ('The Art of War',),
#  ('The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',),
#  ('Shobu Samurai, Project Aryoku (#3)',),
#  ('Scarlett Epstein Hates It Here',),
#  ('Redeeming Love',),
#  ('Mrs. Houdini',),
#  ('Modern Romance',),
#  ('Library of Souls (Miss Peregrineâ\x80\x99s Peculiar Children #3)',),
#  ('I Had a Nice Time And Other Lies...: How to find love & sh*t like that',),
#  ('Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',),
#  ('Frostbite (Vampire Academy #2)',),
#  ('Finders Keepers (Bill Hodges Trilogy #2)',),
#  ('Fables, Vol. 1: Legends in Exile (Fables #1)',),
#  ('Eureka Trivia 6.0',),
#  ('Drive: The Surprising Truth About What Motivates Us',),
#  ('Done Rubbed Out (Reightman & Bailey #1)',),
#  ('Doing It Over (Most Likely To #1)',),
#  ('Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',),
#  ('Close to You',),
#  ('Big Magic: Creative Living Beyond Fear',),
#  ('Anonymous',),
#  ('Amatus',),
#  ('Zealot: The Life and Times of Jesus of Nazareth',),
#  ('You (You #1)',),
#  ('Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',),
#  ('Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',),
#  ('Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',),
#  ('V for Vendetta (V for Vendetta Complete)',),
#  ('The Wright Brothers',),
#  ("The White Queen (The Cousins' War #1)",),
#  ("The Wedding Pact (The O'Malleys #2)",),
#  ('The Time Keeper',),
#  ('The Testament of Mary',),
#  ('The Star-Touched Queen',),
#  ('The Songs of the Gods',),
#  ('The Song of Achilles',),
#  ('The Marriage of Opposites',),
#  ('The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',),
#  ('The First Hostage (J.B. Collins #2)',),
#  ('The Darkest Lie',),
#  ('The Bane Chronicles (The Bane Chronicles #1-11)',),
#  ('Take Me with You',),
#  ('Still Life with Bread Crumbs',),
#  ('Steve Jobs',),
#  ('Sorting the Beef from the Bull: The Science of Food Fraud Forensics',),
#  ('Someone Like You (The Harrisons #2)',),
#  ('So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',),
#  ('Shtum',),
#  ('See America: A Celebration of Our National Parks & Treasured Sites',),
#  ('salt.',),
#  ('Robin War',),
#  ('Rain Fish',),
#  ('Quarter Life Poetry: Poems for the Young, Broke and Hangry',),
#  ('Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',),
#  ('My Mrs. Brown',),
#  ('Made to Stick: Why Some Ideas Survive and Others Die',),
#  ('Luis Paints the World',),
#  ('Luckiest Girl Alive',),
#  ('Looking for Lovely: Collecting the Moments that Matter',),
#  ('Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',),
#  ('Let It Out: A Journey Through Journaling',),
#  ("I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",),
#  ('Hush, Hush (Hush, Hush #1)',),
#  ('Hamilton: The Revolution',),
#  ('God: The Most Unpleasant Character in All Fiction',),
#  ('Glory over Everything: Beyond The Kitchen House',),
#  ('Feathers: Displays of Brilliant Plumage',),
#  ('Every Last Word',),
#  ('Eligible (The Austen Project #4)',),
#  ('El Deafo',),
#  ('Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',),
#  ('Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',),
#  ('Cometh the Hour (The Clifton Chronicles #6)',),
#  ('Code Name Verity (Code Name Verity #1)',),
#  ('City of Glass (The Mortal Instruments #3)',),
#  ('Cell',),
#  ('Catching Jordan (Hundred Oaks)',),
#  ('Carry On, Warrior: Thoughts on Life Unarmed',),
#  ('Buying In: The Secret Dialogue Between What We Buy and Who We Are',),
#  ('Brain on Fire: My Month of Madness',),
#  ("Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",),
#  ('Art Ops Vol. 1',),
#  ('Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',),
#  ('Angels & Demons (Robert Langdon #1)',),
#  ('All the Light We Cannot See',),
#  ('Abstract City',),
#  ('A Time of Torment (Charlie Parker #14)',),
#  ('1491: New Revelations of the Americas Before Columbus',),
#  ('Rook',),
#  ('The Star-Touched Queen',),
#  ('The Silent Sister (Riley MacPherson #1)',),
#  ('The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',),
#  ('The Diary of a Young Girl',),
#  ('Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',),
#  ('Raspberry Pi Electronics Projects for the Evil Genius',),
#  ('Psycho: Sanitarium (Psycho #1.5)',),
#  ('Poisonous (Max Revere Novels #3)',),
#  ('No Love Allowed (Dodge Cove #1)',),
#  ('Murder at the 42nd Street Library (Raymond Ambler #1)',),
#  ('Most Wanted',),
#  ('How to Speak Golf: An Illustrated Guide to Links Lingo',),
#  ('Furiously Happy: A Funny Book About Horrible Things',),
#  ('Everyday Italian: 125 Simple and Delicious Recipes',),
#  ('Eleanor & Park',),
#  ('Dirty (Dive Bar #1)',),
#  ('Boar Island (Anna Pigeon #19)',),
#  ('A Paris Apartment',),
#  ('The Art of Startup Fundraising',),
#  ('Take Me Home Tonight (Rock Star Romance #3)',),
#  ('Off the Hook (Fishing for Trouble #1)',),
#  ('Keep Me Posted',),
#  ("It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle",),
#  ('Grey (Fifty Shades #4)',),
#  ('Exit, Pursued by a Bear',),
#  ('Cravings: Recipes for What You Want to Eat',),
#  ('Born for This: How to Find the Work You Were Meant to Do',),
#  ('Arena',),
#  ('Adultery',),
#  ('11/22/63',),
#  ('10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',),
#  ('Without Shame',),
#  ('Watchmen',),
#  ('Unlimited Intuition Now',),
#  ('The New Brand You: Your New Image Makes the Sale for You',),
#  ('The Book of Mormon',),
#  ('The Art and Science of Low Carbohydrate Living',),
#  ('Suzie Snowflake: One beautiful flake (a self-esteem story)',),
#  ('Fruits Basket, Vol. 9 (Fruits Basket #9)',),
#  ('Dress Your Family in Corduroy and Denim',),
#  ('Art and Fear: Observations on the Perils (and Rewards) of Artmaking',),
#  ('A Shard of Ice (The Black Symphony Saga #1)',),
#  ("A Hero's Curse (The Unseen Chronicles #1)",),
#  ('Zero to One: Notes on Startups, or How to Build the Future',),
#  ('The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)',),
#  ('The New Drawing on the Right Side of the Brain',),
#  ("The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",),
#  ('Smarter Faster Better: The Secrets of Being Productive in Life and Business',),
#  ('Silence in the Dark (Logan Point #4)',),
#  ('Shadows of the Past (Logan Point #1)',),
#  ('Rising Strong',),
#  ('Please Kill Me: The Uncensored Oral History of Punk',),
#  ('Out of Print: City Lights Spotlight No. 14',),
#  ('My Life Next Door (My Life Next Door )',),
#  ("Man's Search for Meaning",),
#  ('Les Fleurs du Mal',),
#  ("Kill 'Em and Leave: Searching for James Brown and the American Soul",),
#  ('John Vassos: Industrial Design for Modern Life',),
#  ('Hystopia: A Novel',),
#  ('Future Shock (Future Shock #1)',),
#  ('Death by Leisure: A Cautionary Tale',),
#  ('Between the World and Me',),
#  ('Being Mortal: Medicine and What Matters in the End',),
#  ('"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',),
#  ('What Happened on Beale Street (Secrets of the South Mysteries #2)',),
#  ('Under the Tuscan Sun',),
#  ('The Whale',),
#  ('The Story of Art',),
#  ('The Great Gatsby',),
#  ('The Good Girl',),
#  ('The Drowning Girls',),
#  ('The Bourne Identity (Jason Bourne #1)',),
#  ("The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",),
#  ('The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',),
#  ('Team of Rivals: The Political Genius of Abraham Lincoln',),
#  ('Sit, Stay, Love',),
#  ('Sister Dear',),
#  ('Shrunken Treasures: Literary Classics, Short, Sweet, and Silly',),
#  ('Nightstruck: A Novel',),
#  ('Meternity',),
#  ('Memoirs of a Geisha',),
#  ('Leave This Song Behind: Teen Poetry at Its Best',),
#  ("King's Folly (The Kinsman Chronicles #1)",),
#  ('John Adams',),
#  ('How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',),
#  ('Good in Bed (Cannie Shapiro #1)',),
#  ('For the Love: Fighting for Grace in a World of Impossible Standards',),
#  ('Delivering the Truth (Quaker Midwife Mystery #1)',),
#  ('Benjamin Franklin: An American Life',),
#  ('At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',),
#  ('A Short History of Nearly Everything',),
#  ('A Gathering of Shadows (Shades of Magic #2)',),
#  ('The Sound Of Love',),
#  ('The Perks of Being a Wallflower',),
#  ('The Mysterious Affair at Styles (Hercule Poirot #1)',),
#  ('The Man Who Mistook His Wife for a Hat and Other Clinical Tales',),
#  ('The Joy of Cooking',),
#  ('The God Delusion',),
#  ('The Barefoot Contessa Cookbook',),
#  ('Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',),
#  ('Mere Christianity',),
#  ('In Cold Blood',),
#  ('How to Stop Worrying and Start Living',),
#  ('Girl, Interrupted',),
#  ('Fun Home: A Family Tragicomic',),
#  ('Fruits Basket, Vol. 6 (Fruits Basket #6)',),
#  ('Deception Point',),
#  ('Death Note, Vol. 6: Give-and-Take (Death Note #6)',),
#  ('Catherine the Great: Portrait of a Woman',),
#  ('Better Homes and Gardens New Cook Book',),
#  ('An Unquiet Mind: A Memoir of Moods and Madness',),
#  ('A Year in Provence (Provence #1)',),
#  ('World Without End (The Pillars of the Earth #2)',),
#  ('Will Grayson, Will Grayson (Will Grayson, Will Grayson)',),
#  ('Where She Went (If I Stay #2)',),
#  ('What If?: Serious Scientific Answers to Absurd Hypothetical Questions',),
#  ('The Raven Boys (The Raven Cycle #1)',),
#  ("The Mathews Men: Seven Brothers and the War Against Hitler's U-boats",),
#  ('The Little Paris Bookshop',),
#  ('The Hiding Place',),
#  ('The Firm',),
#  ('The False Prince (The Ascendance Trilogy #1)',),
#  ('The Crossover',),
#  ('Tell the Wind and Fire',),
#  ("Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",),
#  ('Siddhartha',),
#  ('Red Dragon (Hannibal Lecter #1)',),
#  ('My Mother Was Nuts',),
#  ('Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',),
#  ('Lola and the Boy Next Door (Anna and the French Kiss #2)',),
#  ('Last One Home (New Beginnings #1)',),
#  ('Killing Floor (Jack Reacher #1)',),
#  ('Isla and the Happily Ever After (Anna and the French Kiss #3)',),
#  ('If I Stay (If I Stay #1)',),
#  ('Dracula the Un-Dead',),
#  ('Digital Fortress',),
#  ('Data, A Love Story: How I Gamed Online Dating to Meet My Match',),
#  ('Blue Lily, Lily Blue (The Raven Cycle #3)',),
#  ('Approval Junkie: Adventures in Caring Too Much',),
#  ('Alight (The Generations Trilogy #2)',),
#  ('Vogue Colors A to Z: A Fashion Coloring Book',),
#  ('The Shining (The Shining #1)',),
#  ('The Perfect Play (Play by Play #1)',),
#  ('The Passion of Dolssa',),
#  ('The Jazz of Physics: The Secret Link Between Music and the Structure of the Universe',),
#  ('The Hunger Games (The Hunger Games #1)',),
#  ('The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)',),
#  ('The Beast (Black Dagger Brotherhood #14)',),
#  ('Shopaholic Ties the Knot (Shopaholic #3)',),
#  ('Paper and Fire (The Great Library #2)',),
#  ('No One Here Gets Out Alive',),
#  ('Needful Things',),
#  ('Mockingjay (The Hunger Games #3)',),
#  ('Little Women (Little Women #1)',),
#  ('It',),
#  ('Harry Potter and the Prisoner of Azkaban (Harry Potter #3)',),
#  ('Harry Potter and the Order of the Phoenix (Harry Potter #5)',),
#  ('Harry Potter and the Half-Blood Prince (Harry Potter #6)',),
#  ('Gone with the Wind',),
#  ('Fruits Basket, Vol. 4 (Fruits Basket #4)',),
#  ('Candide',),
#  ('Atlas Shrugged',),
#  ('Animal Farm',),
#  ("A New Earth: Awakening to Your Life's Purpose",),
#  ("'Salem's Lot",),
#  ('Wild: From Lost to Found on the Pacific Crest Trail',),
#  ('When You Are Engulfed in Flames',),
#  ("We the People: The Modern-Day Figures Who Have Reshaped and Affirmed the Founding Fathers' Vision of America",),
#  ('Walk the Edge (Thunder Road #2)',),
#  ('Voyager (Outlander #3)',),
#  ('Very Good Lives: The Fringe Benefits of Failure and the Importance of Imagination',),
#  ('Three-Martini Lunch',),
#  ('The Wild Robot',),
#  ('The Undomestic Goddess',),
#  ('The Silkworm (Cormoran Strike #2)',),
#  ('The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)',),
#  ('The Rose & the Dagger (The Wrath and the Dawn #2)',),
#  ('The Rise of Theodore Roosevelt (Theodore Roosevelt #1)',),
#  ('The Red Tent',),
#  ('The Purpose Driven Life: What on Earth Am I Here for?',),
#  ('The Paris Wife',),
#  ('The Nightingale',),
#  ('The New Guy (and Other Senior Year Distractions)',),
#  ('The Nanny Diaries (Nanny #1)',),
#  ('The Lonely Ones',),
#  ("The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses",),
#  ('The Land of 10,000 Madonnas',),
#  ("The Husband's Secret",),
#  ("The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)",),
#  ('The Goldfinch',),
#  ('The Girl with All the Gifts',),
#  ('The Exiled',),
#  ('The End of Faith: Religion, Terror, and the Future of Reason',),
#  ('The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements',),
#  ('The Demon-Haunted World: Science as a Candle in the Dark',),
#  ('The Day the Crayons Came Home (Crayons)',),
#  ('The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',),
#  ('The Complete Poems',),
#  ('The Book of Basketball: The NBA According to The Sports Guy',),
#  ('The Blind Side: Evolution of a Game',),
#  ('The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution',),
#  ('Stiff: The Curious Lives of Human Cadavers',),
#  ('Something Borrowed (Darcy & Rachel #1)',),
#  ('Seven Brief Lessons on Physics',),
#  ('Saga, Volume 3 (Saga (Collected Editions) #3)',),
#  ('Rogue Lawyer (Rogue Lawyer #1)',),
#  ('Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',),
#  ('Red: The True Story of Red Riding Hood',),
#  ('Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',),
#  ('Original Fake',),
#  ('Neither Here nor There: Travels in Europe',),
#  ('Naked',),
#  ('Life Without a Recipe',),
#  ('Legend (Legend #1)',),
#  ("Lamb: The Gospel According to Biff, Christ's Childhood Pal",),
#  ('Lady Renegades (Rebel Belle #3)',),
#  ('Is Everyone Hanging Out Without Me? (And Other Concerns)',),
#  ('Into the Wild',),
#  ('Inferno (Robert Langdon #4)',),
#  ("In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin",),
#  ('If I Run (If I Run #1)',),
#  ('Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',),
#  ('Heir to the Sky',),
#  ('Gratitude',),
#  ('Gone Girl',),
#  ('Golden (Heart of Dread #3)',),
#  ('Friday Night Lights: A Town, a Team, and a Dream',),
#  ('Fire Bound (Sea Haven/Sisters of the Heart #5)',),
#  ('Extreme Prey (Lucas Davenport #26)',),
#  ('Eragon (The Inheritance Cycle #1)',),
#  ('Dracula',),
#  ('Dead Wake: The Last Crossing of the Lusitania',),
#  ('Dark Places',),
#  ('Crazy Rich Asians (Crazy Rich Asians #1)',),
#  ('Breaking Dawn (Twilight #4)',),
#  ('Brave Enough',),
#  ('Boy Meets Boy',),
#  ('Blink: The Power of Thinking Without Thinking',),
#  ('Between Shades of Gray',),
#  ('Beautiful Creatures (Caster Chronicles #1)',),
#  ('Ash',),
#  ('Annie on My Mind',),
#  ('A Walk in the Woods: Rediscovering America on the Appalachian Trail',),
#  ('A Heartbreaking Work of Staggering Genius',),
#  ('The Sense of an Ending',),
#  ('Life',),
#  ("Kindle Paperwhite User's Guide",),
#  ('H is for Hawk',),
#  ('Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',),
#  ('While You Were Mine',),
#  ('Where Lightning Strikes (Bleeding Stars #3)',),
#  ("When I'm Gone",),
#  ('Ways of Seeing',),
#  ('Twenty Love Poems and a Song of Despair',),
#  ('Travels with Charley: In Search of America',),
#  ('The Tumor',),
#  ('The Story of Hong Gildong',),
#  ('The Silent Twin (Detective Jennifer Knight #3)',),
#  ('The Secret Healer',),
#  ('The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',),
#  ('The Republic',),
#  ('The Odyssey',),
#  ("The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",),
#  ('The Name of the Wind (The Kingkiller Chronicle #1)',),
#  ('The Hook Up (Game On #1)',),
#  ('The Haters',),
#  ('The Bhagavad Gita',),
#  ('The Bette Davis Club',),
#  ('The Art of Not Breathing',),
#  ('Starlark',),
#  ('Skip Beat!, Vol. 01 (Skip Beat! #1)',),
#  ('Shameless',),
#  ('Shadow Rites (Jane Yellowrock #10)',),
#  ('Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',),
#  ('Paper Girls, Vol. 1 (Paper Girls #1-5)',),
#  ('Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',),
#  ('On the Road (Duluoz Legend)',),
#  ('Off Sides (Off #1)',),
#  ('Myriad (Prentor #1)',),
#  ('Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',),
#  ('Lost Among the Living',),
#  ('Lord of the Flies',),
#  ('Listen to Me (Fusion #1)',),
#  ('Kitchens of the Great Midwest',),
#  ('Jane Eyre',),
#  ('Imperfect Harmony',),
#  ('Icing (Aces Hockey #2)',),
#  ('Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',),
#  ("Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",),
#  ('Giant Days, Vol. 1 (Giant Days #1-4)',),
#  ('Fruits Basket, Vol. 1 (Fruits Basket #1)',),
#  ('Forever Rockers (The Rocker #12)',),
#  ('Fighting Fate (Fighting #6)',),
#  ('Eat, Pray, Love',),
#  ('Deep Under (Walker Security #1)',),
#  ("Choosing Our Religion: The Spiritual Lives of America's Nones",),
#  ('Charlie and the Chocolate Factory (Charlie Bucket #1)',),
#  ('Bright Lines',),
#  ('Bounty (Colorado Mountain #7)',),
#  ('Blood Defense (Samantha Brinkman #1)',),
#  ('Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',),
#  ('Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',),
#  ('1,000 Places to See Before You Die',),
#  ('worldend',),
#  ('America',),
#  ('catchme',)]

# %%
ques3= cr.execute("SELECT bookname,rate from book1000 WHERE rate != 3")
ques3.fetchall()
# Out:
# [('Tipping the Velvet', 1),
#  ('Soumission', 1),
#  ('Sharp Objects', 4),
#  ('Sapiens: A Brief History of Humankind', 5),
#  ('The Requiem Red', 1),
#  ('The Dirty Little Secrets of Getting Your Dream Job', 4),
#  ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   4),
#  ('The Black Maria', 1),
#  ('Starving Hearts (Triangular Trade Trilogy, #1)', 2),
#  ("Shakespeare's Sonnets", 4),
#  ('Set Me Free', 5),
#  ("Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 5),
#  ('Rip it Up and Start Again', 5),
#  ('Olio', 1),
#  ('Mesaerion: The Best Science Fiction Stories 1800-1849', 1),
#  ('Libertarianism for Beginners', 2),
#  ("It's Only the Himalayas", 2),
#  ('In Her Wake', 1),
#  ('How Music Works', 2),
#  ('Chase Me (Paris Nights #2)', 5),
#  ('Black Dust', 5),
#  ('Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe', 5),
#  ('Wall and Piece', 4),
#  ('The Four Agreements: A Practical Guide to Personal Freedom', 5),
#  ('The Elephant Tree', 5),
#  ('The Bear and the Piano', 1),
#  ("Sophie's World", 5),
#  ('Maude (1883-1993):She Grew Up with the country', 2),
#  ('In a Dark, Dark Wood', 1),
#  ('Behind Closed Doors', 4),
#  ("You can't bury them all: Poems", 2),
#  ('Reasons to Stay Alive', 2),
#  ('Private Paris (Private #10)', 5),
#  ('#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 5),
#  ('Without Borders (Wanderlove #1)', 2),
#  ('When We Collided', 1),
#  ('We Love You, Charlie Freeman', 5),
#  ('Untitled Collection: Sabbath Poems 2014', 4),
#  ('Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   4),
#  ('Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   1),
#  ('Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 1),
#  ('This One Summer', 4),
#  ('Thirst', 5),
#  ('The Torch Is Passed: A Harding Family Story', 1),
#  ('The Secret of Dreadwillow Carse', 1),
#  ('The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#   1),
#  ('The Past Never Ends', 4),
#  ('The Nameless City (The Nameless City #1)', 4),
#  ("The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 4),
#  ('The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   4),
#  ('The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   5),
#  ('The Gutsy Girl: Escapades for Your Life of Epic Adventure', 1),
#  ('The Electric Pencil: Drawings from Inside State Hospital No. 3', 1),
#  ('The Death of Humanity: and the Case for Life', 4),
#  ('The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   1),
#  ("The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 5),
#  ('Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   4),
#  ('Soul Reader', 2),
#  ('Security', 2),
#  ('Saga, Volume 5 (Saga (Collected Editions) #5)', 2),
#  ('Reskilling America: Learning to Labor in the Twenty-First Century', 2),
#  ('Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   5),
#  ('Princess Between Worlds (Wide-Awake Princess #5)', 5),
#  ('Pop Gun War, Volume 1: Gift', 1),
#  ('Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   2),
#  ('Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 4),
#  ('orange: The Complete Collection 1 (orange: The Complete Collection #1)', 1),
#  ('Online Marketing for Busy Authors: A Step-By-Step Guide', 1),
#  ('Obsidian (Lux #1)', 2),
#  ('My Paris Kitchen: Recipes and Stories', 2),
#  ('Masks and Shadows', 2),
#  ('Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   4),
#  ('Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 2),
#  ('Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 2),
#  ('Layered: Baking, Building, and Styling Spectacular Cakes', 1),
#  ('Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 2),
#  ('Join', 5),
#  ('In the Country We Love: My Family Divided', 4),
#  ('Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 5),
#  ('I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   2),
#  ('How to Be Miserable: 40 Strategies You Already Use', 1),
#  ('Her Backup Boyfriend (The Sorensen Family #1)', 1),
#  ('Giant Days, Vol. 2 (Giant Days #5-8)', 2),
#  ('First and First (Five Boroughs #3)', 4),
#  ('Fifty Shades Darker (Fifty Shades #2)', 1),
#  ('Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#   2),
#  ("Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#   2),
#  ('Danganronpa Volume 1', 4),
#  ('Codename Baboushka, Volume 1: The Conclave of Death', 4),
#  ('Camp Midnight', 4),
#  ('Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 5),
#  ('Bossypants', 2),
#  ('Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   2),
#  ('Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#   2),
#  ('Algorithms to Live By: The Computer Science of Human Decisions', 1),
#  ('A World of Flavor: Your Gluten Free Passport', 1),
#  ('A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 5),
#  ('A Murder in Time', 1),
#  ('A Flight of Arrows (The Pathfinders #2)', 5),
#  ('A Fierce and Subtle Poison', 4),
#  ('A Court of Thorns and Roses (A Court of Thorns and Roses #1)', 1),
#  ('(Un)Qualified: How God Uses Broken People to Do Big Things', 5),
#  ('You Are What You Love: The Spiritual Power of Habit', 4),
#  ("William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#   4),
#  ('Tuesday Nights in 1980', 2),
#  ('Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#   1),
#  ('Thirteen Reasons Why', 1),
#  ('The White Cat and the Monk: A Retelling of the Poem â\x80\x9cPangur BÃ¡nâ\x80\x9d',
#   4),
#  ('The Wedding Dress', 1),
#  ('The Vacationers', 4),
#  ('The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future', 5),
#  ('The Stranger', 4),
#  ('The Shadow Hero (The Shadow Hero)', 1),
#  ('The Secret (The Secret #1)', 4),
#  ('The Regional Office Is Under Attack!', 5),
#  ('The Psychopath Test: A Journey Through the Madness Industry', 2),
#  ('The Project', 1),
#  ('The Power of Now: A Guide to Spiritual Enlightenment', 2),
#  ("The Omnivore's Dilemma: A Natural History of Four Meals", 2),
#  ('The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 5),
#  ('The Murder of Roger Ackroyd (Hercule Poirot #4)', 4),
#  ("The Matchmaker's Playbook (Wingmen Inc. #1)", 1),
#  ('The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   2),
#  ('The Long Shadow of Small Ghosts: Murder and Memory in an American City', 1),
#  ('The Kite Runner', 4),
#  ('The House by the Lake', 1),
#  ('The Glittering Court (The Glittering Court #1)', 1),
#  ('The Girl on the Train', 2),
#  ('The Genius of Birds', 1),
#  ('The Emerald Mystery', 2),
#  ('The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   1),
#  ("The Artist's Way: A Spiritual Path to Higher Creativity", 5),
#  ('The Art of War', 5),
#  ('The Argonauts', 2),
#  ('Suddenly in Love (Lake Haven #1)', 2),
#  ('Something More Than This', 4),
#  ('Soft Apocalypse', 2),
#  ("So You've Been Publicly Shamed", 2),
#  ('Shoe Dog: A Memoir by the Creator of NIKE', 2),
#  ('Secrets and Lace (Fatal Hearts #1)', 1),
#  ('Scarlett Epstein Hates It Here', 5),
#  ('Romero and Juliet: A Tragic Tale of Love and Zombies', 1),
#  ('Redeeming Love', 5),
#  ('Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#   1),
#  ('Poems That Make Grown Women Cry', 4),
#  ('Nightingale, Sing', 1),
#  ('Night Sky with Exit Wounds', 1),
#  ('Mrs. Houdini', 5),
#  ('Modern Romance', 5),
#  ('Miss Peregrineâ\x80\x99s Home for Peculiar Children (Miss Peregrineâ\x80\x99s Peculiar Children #1)',
#   1),
#  ('Louisa: The Extraordinary Life of Mrs. Adams', 2),
#  ('Library of Souls (Miss Peregrineâ\x80\x99s Peculiar Children #3)', 5),
#  ('Large Print Heart of the Pride', 2),
#  ('I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 4),
#  ('Hollow City (Miss Peregrineâ\x80\x99s Peculiar Children #2)', 1),
#  ('Grumbles', 2),
#  ('Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   4),
#  ('Frostbite (Vampire Academy #2)', 5),
#  ('Follow You Home', 1),
#  ('First Steps for New Christians (Print Edition)', 1),
#  ('Finders Keepers (Bill Hodges Trilogy #2)', 5),
#  ('Fables, Vol. 1: Legends in Exile (Fables #1)', 4),
#  ('Eureka Trivia 6.0', 4),
#  ('Drive: The Surprising Truth About What Motivates Us', 4),
#  ('Done Rubbed Out (Reightman & Bailey #1)', 5),
#  ('Dark Notes', 5),
#  ('Close to You', 4),
#  ('Chasing Heaven: What Dying Taught Me About Living', 2),
#  ('Becoming Wise: An Inquiry into the Mystery and Art of Living', 2),
#  ('Beauty Restored (Riley Family Legacy Novellas #3)', 2),
#  ('Batman: The Long Halloween (Batman)', 2),
#  ('Batman: The Dark Knight Returns (Batman)', 5),
#  ("Ayumi's Violin", 2),
#  ('Anonymous', 4),
#  ('Amid the Chaos', 1),
#  ('Amatus', 5),
#  ('Agnostic: A Spirited Manifesto', 5),
#  ('You (You #1)', 5),
#  ('Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', 4),
#  ('Wild Swans', 2),
#  ('Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   4),
#  ('Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   4),
#  ("What's It Like in Space?: Stories from Astronauts Who've Been There", 2),
#  ('We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)', 1),
#  ("Walt Disney's Alice in Wonderland", 5),
#  ('V for Vendetta (V for Vendetta Complete)', 4),
#  ('Until Friday Night (The Field Party #1)', 2),
#  ('Unbroken: A World War II Story of Survival, Resilience, and Redemption', 2),
#  ('Twenty Yawns', 2),
#  ('Through the Woods', 2),
#  ('This Is Where It Ends', 2),
#  ('The Year of Magical Thinking', 2),
#  ('The Wright Brothers', 4),
#  ("The White Queen (The Cousins' War #1)", 5),
#  ('The Time Keeper', 5),
#  ('The Testament of Mary', 4),
#  ('The Star-Touched Queen', 5),
#  ('The Songs of the Gods', 5),
#  ('The Song of Achilles', 5),
#  ('The Rosie Project (Don Tillman #1)', 1),
#  ('The Marriage of Opposites', 4),
#  ('The Lucifer Effect: Understanding How Good People Turn Evil', 1),
#  ('The Long Haul (Diary of a Wimpy Kid #9)', 1),
#  ('The Loney', 1),
#  ('The Last Mile (Amos Decker #2)', 2),
#  ('The Immortal Life of Henrietta Lacks', 2),
#  ('The Hidden Oracle (The Trials of Apollo #1)', 2),
#  ('The Guilty (Will Robie #4)', 2),
#  ('The Dovekeepers', 1),
#  ('The Darkest Lie', 5),
#  ('The Bane Chronicles (The Bane Chronicles #1-11)', 4),
#  ('The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâ\x80\x99s Most Precious Manuscripts',
#   1),
#  ('The 14th Colony (Cotton Malone #11)', 1),
#  ('That Darkness (Gardiner and Renner #1)', 1),
#  ('Tastes Like Fear (DI Marnie Rome #3)', 1),
#  ('Swell: A Year of Waves', 1),
#  ('Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 5),
#  ('Steve Jobs', 5),
#  ('Sorting the Beef from the Bull: The Science of Food Fraud Forensics', 4),
#  ('Someone Like You (The Harrisons #2)', 5),
#  ('So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)', 4),
#  ('Shtum', 4),
#  ('salt.', 4),
#  ('Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)', 2),
#  ('Quarter Life Poetry: Poems for the Young, Broke and Hangry', 5),
#  ('Once Was a Time', 2),
#  ('Old School (Diary of a Wimpy Kid #10)', 5),
#  ('No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon', 2),
#  ('Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#   2),
#  ('My Name Is Lucy Barton', 1),
#  ('My Kind of Crazy', 1),
#  ('Mr. Mercedes (Bill Hodges Trilogy #1)', 1),
#  ('More Than Music (Chasing the Dream #1)', 2),
#  ('Made to Stick: Why Some Ideas Survive and Others Die', 5),
#  ('Lowriders to the Center of the Earth (Lowriders in Space #2)', 2),
#  ('Love Is a Mix Tape (Music #1)', 1),
#  ('Looking for Lovely: Collecting the Moments that Matter', 5),
#  ('Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#   4),
#  ('Let It Out: A Journey Through Journaling', 5),
#  ('Lady Midnight (The Dark Artifices #1)', 5),
#  ("It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes", 1),
#  ('Island of Dragons (Unwanteds #7)', 1),
#  ("I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#   4),
#  ('I Am Pilgrim (Pilgrim #1)', 4),
#  ('Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   5),
#  ('Hold Your Breath (Search and Rescue #1)', 1),
#  ('Greek Mythic History', 5),
#  ('God: The Most Unpleasant Character in All Fiction', 5),
#  ('Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   4),
#  ('El Deafo', 5),
#  ('Eight Hundred Grapes', 4),
#  ('Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#   5),
#  ('Eat Fat, Get Thin', 2),
#  ("Don't Get Caught", 1),
#  ('Doctor Sleep (The Shining #2)', 2),
#  ('Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#   5),
#  ('Dear Mr. Knightley', 5),
#  ('Daily Fantasy Sports', 1),
#  ('Crazy Love: Overwhelmed by a Relentless God', 2),
#  ('Code Name Verity (Code Name Verity #1)', 4),
#  ('Clockwork Angel (The Infernal Devices #1)', 1),
#  ('City of Glass (The Mortal Instruments #3)', 4),
#  ('City of Fallen Angels (The Mortal Instruments #4)', 4),
#  ('City of Bones (The Mortal Instruments #1)', 1),
#  ('City of Ashes (The Mortal Instruments #2)', 1),
#  ('Cell', 4),
#  ('Carrie', 2),
#  ('Buying In: The Secret Dialogue Between What We Buy and Who We Are', 4),
#  ('Brain on Fire: My Month of Madness', 5),
#  ('Batman: Europa', 2),
#  ('Barefoot Contessa Back to Basics', 1),
#  ("Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   5),
#  ('Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   4),
#  ('Angels Walking (Angels Walking #1)', 2),
#  ('All the Light We Cannot See', 5),
#  ('Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection', 2),
#  ('Abstract City', 5),
#  ('A Time of Torment (Charlie Parker #14)', 5),
#  ('A Study in Scarlet (Sherlock Holmes #1)', 2),
#  ('A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#   2),
#  ("A People's History of the United States", 2),
#  ('A Man Called Ove', 1),
#  ('A Brush of Wings (Angels Walking #3)', 1),
#  ('Searching for Meaning in Gailana', 1),
#  ('Rook', 4),
#  ('My Kitchen Year: 136 Recipes That Saved My Life', 2),
#  ('13 Hours: The Inside Account of What Really Happened In Benghazi', 1),
#  ('Tipping Point for Planet Earth: How Close Are We to the Edge?', 1),
#  ('The Star-Touched Queen', 5),
#  ('The Silent Sister (Riley MacPherson #1)', 5),
#  ('The Midnight Watch: A Novel of the Titanic and the Californian', 1),
#  ('The Lonely City: Adventures in the Art of Being Alone', 2),
#  ('The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   4),
#  ('The Golden Condom: And Other Essays on Love Lost and Found', 1),
#  ('The Epidemic (The Program 0.6)', 5),
#  ('The Dinner Party', 2),
#  ('Stars Above (The Lunar Chronicles #4.5)', 2),
#  ('Raspberry Pi Electronics Projects for the Evil Genius', 4),
#  ('Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two', 1),
#  ('Psycho: Sanitarium (Psycho #1.5)', 5),
#  ('One with You (Crossfire #5)', 4),
#  ('No Love Allowed (Dodge Cove #1)', 4),
#  ('Murder at the 42nd Street Library (Raymond Ambler #1)', 4),
#  ('Love, Lies and Spies', 2),
#  ('How to Speak Golf: An Illustrated Guide to Links Lingo', 5),
#  ('Hide Away (Eve Duncan #20)', 1),
#  ('Furiously Happy: A Funny Book About Horrible Things', 4),
#  ('Everyday Italian: 125 Simple and Delicious Recipes', 5),
#  ("Equal Is Unfair: America's Misguided Fight Against Income Inequality", 1),
#  ('Eleanor & Park', 5),
#  ('Dirty (Dive Bar #1)', 4),
#  ('Can You Keep a Secret? (Fear Street Relaunch #4)', 1),
#  ('A Paris Apartment', 4),
#  ('A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   1),
#  ('Troublemaker: Surviving Hollywood and Scientology', 2),
#  ('The Widow', 2),
#  ('The Sleep Revolution: Transforming Your Life, One Night at a Time', 4),
#  ('The Improbability of Love', 1),
#  ('Sleeping Giants (Themis Files #1)', 1),
#  ('Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   2),
#  ('Mothering Sunday', 2),
#  ('Mother, Can You Not?', 5),
#  ('M Train', 1),
#  ('Lilac Girls', 2),
#  ('Lies and Other Acts of Love', 1),
#  ('Lab Girl', 1),
#  ('Keep Me Posted', 4),
#  ('Grey (Fifty Shades #4)', 4),
#  ('Exit, Pursued by a Bear', 4),
#  ('Born for This: How to Find the Work You Were Meant to Do', 5),
#  ('Arena', 4),
#  ('Adultery', 5),
#  ("A Gentleman's Position (Society of Gentlemen #3)", 5),
#  ('10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
#   2),
#  ('10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 5),
#  ('Without Shame', 5),
#  ('Watchmen', 4),
#  ('Unlimited Intuition Now', 4),
#  ('Underlying Notes', 2),
#  ('The Shack', 1),
#  ('The New Brand You: Your New Image Makes the Sale for You', 5),
#  ('The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   4),
#  ('The Flowers Lied', 2),
#  ('The Fabric of the Cosmos: Space, Time, and the Texture of Reality', 1),
#  ('The Art and Science of Low Carbohydrate Living', 5),
#  ('The Alien Club', 1),
#  ('Suzie Snowflake: One beautiful flake (a self-esteem story)', 5),
#  ('Nap-a-Roo', 1),
#  ('NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   4),
#  ('Modern Day Fables', 2),
#  ("If I Gave You God's Phone Number....: Searching for Spirituality in America",
#   1),
#  ('Fruits Basket, Vol. 9 (Fruits Basket #9)', 4),
#  ("Don't Forget Steven", 1),
#  ("Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster",
#   2),
#  ('Art and Fear: Observations on the Perils (and Rewards) of Artmaking', 4),
#  ('23 Degrees South: A Tropical Tale of Changing Whether...', 2),
#  ('Why Not Me?', 1),
#  ('When Breath Becomes Air', 2),
#  ('Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel', 2),
#  ('The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', 5),
#  ("The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#   4),
#  ('The Martian (The Martian #1)', 2),
#  ('The High Mountains of Portugal', 1),
#  ('The Grownup', 1),
#  ("The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#   1),
#  ('South of Sunshine', 1),
#  ('Smarter Faster Better: The Secrets of Being Productive in Life and Business',
#   5),
#  ('Shadows of the Past (Logan Point #1)', 5),
#  ('Roller Girl', 5),
#  ('Proofs of God: Classical Arguments from Tertullian to Barth', 1),
#  ('Please Kill Me: The Uncensored Oral History of Punk', 4),
#  ('Out of Print: City Lights Spotlight No. 14', 5),
#  ('My Life Next Door (My Life Next Door )', 5),
#  ("Miller's Valley", 2),
#  ("Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations",
#   2),
#  ('Les Fleurs du Mal', 5),
#  ('Left Behind (Left Behind #1)', 2),
#  ("Kill 'Em and Leave: Searching for James Brown and the American Soul", 5),
#  ('Kierkegaard: A Christian Missionary to Christians', 1),
#  ('John Vassos: Industrial Design for Modern Life', 4),
#  ("I'll Give You the Sun", 1),
#  ('I Will Find You', 1),
#  ('Hystopia: A Novel', 4),
#  ('Howl and Other Poems', 2),
#  ('History of Beauty', 4),
#  ("Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back",
#   2),
#  ('Future Shock (Future Shock #1)', 5),
#  ("Ender's Game (The Ender Quintet #1)", 1),
#  ('Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World',
#   1),
#  ('Death by Leisure: A Cautionary Tale', 4),
#  ("Brazen: The Courage to Find the You That's Been Hiding", 2),
#  ('Between the World and Me', 4),
#  ('Being Mortal: Medicine and What Matters in the End', 4),
#  ('32 Yolks', 2),
#  ('"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#   5),
#  ('Wildlife of New York: A Five-Borough Coloring Book', 2),
#  ('What Happened on Beale Street (Secrets of the South Mysteries #2)', 5),
#  ('Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#   2),
#  ("Toddlers Are A**holes: It's Not Your Fault", 1),
#  ("The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible",
#   1),
#  ('The Whale', 4),
#  ('The Story of Art', 4),
#  ('The Origin of Species', 4),
#  ('The Great Gatsby', 4),
#  ('The Glass Castle', 1),
#  ("The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#   1),
#  ('The Bourne Identity (Jason Bourne #1)', 4),
#  ("The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   5),
#  ('The Art Book', 2),
#  ('The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#   4),
#  ('Team of Rivals: The Political Genius of Abraham Lincoln', 5),
#  ('Steal Like an Artist: 10 Things Nobody Told You About Being Creative', 2),
#  ('Sister Dear', 4),
#  ('Rich Dad, Poor Dad', 1),
#  ('Raymie Nightingale', 2),
#  ('Playing from the Heart', 1),
#  ('Nightstruck: A Novel', 4),
#  ('Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   5),
#  ('Like Never Before (Walker Family #2)', 2),
#  ('Life of Pi', 4),
#  ('Leave This Song Behind: Teen Poetry at Its Best', 5),
#  ("King's Folly (The Kinsman Chronicles #1)", 5),
#  ('John Adams', 4),
#  ('How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#   4),
#  ('How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking', 2),
#  ('Good in Bed (Cannie Shapiro #1)', 5),
#  ('Fruits Basket, Vol. 7 (Fruits Basket #7)', 1),
#  ('Finding God in the Ruins: How God Redeems Pain', 2),
#  ('Every Heart a Doorway (Every Heart A Doorway #1)', 5),
#  ('Delivering the Truth (Quaker Midwife Mystery #1)', 4),
#  ('Counted With the Stars (Out from Egypt #1)', 5),
#  ('Chronicles, Vol. 1', 2),
#  ('Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality', 1),
#  ('At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#   5),
#  ('A Summer In Europe', 2),
#  ('A Short History of Nearly Everything', 5),
#  ('A Gathering of Shadows (Shades of Magic #2)', 4),
#  ('The Sound Of Love', 5),
#  ('The Rise and Fall of the Third Reich: A History of Nazi Germany', 2),
#  ('The Mysterious Affair at Styles (Hercule Poirot #1)', 4),
#  ('The Man Who Mistook His Wife for a Hat and Other Clinical Tales', 4),
#  ('The Makings of a Fatherless Child', 2),
#  ('The Joy of Cooking', 4),
#  ('The Invention of Wings', 1),
#  ('The Hobbit (Middle-Earth Universe)', 5),
#  ('The Great Railway Bazaar', 1),
#  ('The Golden Compass (His Dark Materials #1)', 1),
#  ('The Girl You Left Behind (The Girl You Left Behind #1)', 1),
#  ('The Fellowship of the Ring (The Lord of the Rings #1)', 2),
#  ('The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#   5),
#  ('The Barefoot Contessa Cookbook', 5),
#  ("Tell the Wolves I'm Home", 2),
#  ('Pride and Prejudice', 4),
#  ('Musicophilia: Tales of Music and the Brain', 1),
#  ('Me Before You (Me Before You #1)', 1),
#  ('In the Woods (Dublin Murder Squad #1)', 2),
#  ('In Cold Blood', 4),
#  ('How to Stop Worrying and Start Living', 5),
#  ('Give It Back', 2),
#  ('Fun Home: A Family Tragicomic', 4),
#  ('Fruits Basket, Vol. 6 (Fruits Basket #6)', 4),
#  ('Deception Point', 4),
#  ('Catherine the Great: Portrait of a Woman', 4),
#  ('A Year in Provence (Provence #1)', 4),
#  ('World Without End (The Pillars of the Earth #2)', 4),
#  ('Will Grayson, Will Grayson (Will Grayson, Will Grayson)', 4),
#  ('Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis',
#   2),
#  ('Where She Went (If I Stay #2)', 4),
#  ('What If?: Serious Scientific Answers to Absurd Hypothetical Questions', 4),
#  ('Two Summers', 1),
#  ('This Is Your Brain on Music: The Science of a Human Obsession', 1),
#  ('The Secret Garden', 4),
#  ('The Raven King (The Raven Cycle #4)', 2),
#  ('The Raven Boys (The Raven Cycle #1)', 4),
#  ('The Power Greens Cookbook: 140 Delicious Superfood Recipes', 5),
#  ('The Metamorphosis', 1),
#  ("The Mathews Men: Seven Brothers and the War Against Hitler's U-boats", 5),
#  ('The Hiding Place', 4),
#  ('The Fault in Our Stars', 1),
#  ('The False Prince (The Ascendance Trilogy #1)', 5),
#  ('The Expatriates', 2),
#  ('The Dream Thieves (The Raven Cycle #2)', 1),
#  ('The Darkest Corners', 5),
#  ('The Crossover', 4),
#  ('The 5th Wave (The 5th Wave #1)', 2),
#  ('Tell Me Three Things', 1),
#  ("Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",
#   4),
#  ('Siddhartha', 5),
#  ('Shiver (The Wolves of Mercy Falls #1)', 5),
#  ('Peak: Secrets from the New Science of Expertise', 2),
#  ('My Mother Was Nuts', 4),
#  ('Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens', 5),
#  ('Maybe Something Beautiful: How Art Transformed a Neighborhood', 1),
#  ('Lola and the Boy Next Door (Anna and the French Kiss #2)', 4),
#  ('Logan Kade (Fallen Crest High #5.5)', 2),
#  ('Killing Floor (Jack Reacher #1)', 4),
#  ('Kill the Boy Band', 5),
#  ('Isla and the Happily Ever After (Anna and the French Kiss #3)', 5),
#  ('If I Stay (If I Stay #1)', 5),
#  ("I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1)", 2),
#  ('Harry Potter and the Deathly Hallows (Harry Potter #7)', 1),
#  ('Fruits Basket, Vol. 5 (Fruits Basket #5)', 1),
#  ('Foundation (Foundation (Publication Order) #1)', 1),
#  ('Fool Me Once', 1),
#  ('Find Her (Detective D.D. Warren #8)', 1),
#  ('Evicted: Poverty and Profit in the American City', 1),
#  ('Drama', 2),
#  ('Dracula the Un-Dead', 5),
#  ('Digital Fortress', 5),
#  ('Death Note, Vol. 5: Whiteout (Death Note #5)', 1),
#  ('Critique of Pure Reason', 1),
#  ('Booked', 5),
#  ('Blue Lily, Lily Blue (The Raven Cycle #3)', 5),
#  ('Approval Junkie: Adventures in Caring Too Much', 5),
#  ('An Abundance of Katherines', 5),
#  ("America's War for the Greater Middle East: A Military History", 2),
#  ('Alight (The Generations Trilogy #2)', 4),
#  ("A Girl's Guide to Moving On (New Beginnings #2)", 1),
#  ('A Game of Thrones (A Song of Ice and Fire #1)', 2),
#  ('A Feast for Crows (A Song of Ice and Fire #4)', 4),
#  ('Vogue Colors A to Z: A Fashion Coloring Book', 4),
#  ("The Pilgrim's Progress", 2),
#  ('The Passion of Dolssa', 5),
#  ('The Hunger Games (The Hunger Games #1)', 5),
#  ('The Hound of the Baskervilles (Sherlock Holmes #5)', 2),
#  ('The Gunning of America: Business and the Making of American Gun Culture',
#   4),
#  ("The Geography of Bliss: One Grump's Search for the Happiest Places in the World",
#   2),
#  ('The Demonists (Demonist #1)', 2),
#  ('The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4)',
#   2),
#  ('The Beast (Black Dagger Brotherhood #14)', 5),
#  ('Some Women', 5),
#  ('Shopaholic Ties the Knot (Shopaholic #3)', 5),
#  ('Paper and Fire (The Great Library #2)', 5),
#  ('Outlander (Outlander #1)', 5),
#  ('No One Here Gets Out Alive', 5),
#  ('Night Shift (Night Shift #1-20)', 4),
#  ('Needful Things', 4),
#  ('Mockingjay (The Hunger Games #3)', 4),
#  ('Misery', 2),
#  ('Little Women (Little Women #1)', 4),
#  ('Harry Potter and the Prisoner of Azkaban (Harry Potter #3)', 4),
#  ('Harry Potter and the Order of the Phoenix (Harry Potter #5)', 4),
#  ('Harry Potter and the Half-Blood Prince (Harry Potter #6)', 5),
#  ('Harry Potter and the Chamber of Secrets (Harry Potter #2)', 1),
#  ('God Is Not Great: How Religion Poisons Everything', 1),
#  ('Girl With a Pearl Earring', 1),
#  ('Fruits Basket, Vol. 4 (Fruits Basket #4)', 4),
#  ('Far From True (Promise Falls Trilogy #2)', 2),
#  ('Dark Lover (Black Dagger Brotherhood #1)', 1),
#  ('Confessions of a Shopaholic (Shopaholic #1)', 2),
#  ('Can You Keep a Secret?', 1),
#  ('Atlas Shrugged', 5),
#  ('A Walk to Remember', 1),
#  ("A New Earth: Awakening to Your Life's Purpose", 5),
#  ('A History of God: The 4,000-Year Quest of Judaism, Christianity, and Islam',
#   1),
#  ("'Salem's Lot", 4),
#  ('Zero History (Blue Ant #3)', 1),
#  ('World War Z: An Oral History of the Zombie War', 1),
#  ("Where'd You Go, Bernadette", 1),
#  ('When You Are Engulfed in Flames', 5),
#  ('We Are All Completely Beside Ourselves', 1),
#  ('Voyager (Outlander #3)', 5),
#  ('Vegan Vegetarian Omnivore: Dinner for Everyone at the Table', 2),
#  ('Unstuffed: Decluttering Your Home, Mind, and Soul', 1),
#  ('Under the Banner of Heaven: A Story of Violent Faith', 1),
#  ('Two Boys Kissing', 2),
#  ('Twilight (Twilight #1)', 2),
#  ('Twenties Girl', 2),
#  ("Trespassing Across America: One Man's Epic, Never-Done-Before (and Sort of Illegal) Hike Across the Heartland",
#   1),
#  ('Thinking, Fast and Slow', 1),
#  ('The Undomestic Goddess', 4),
#  ('The Travelers', 1),
#  ('The Tipping Point: How Little Things Can Make a Big Difference', 2),
#  ('The Thing About Jellyfish', 1),
#  ('The Stand', 2),
#  ('The Smitten Kitchen Cookbook', 1),
#  ('The Silkworm (Cormoran Strike #2)', 5),
#  ('The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)', 5),
#  ('The Rose & the Dagger (The Wrath and the Dawn #2)', 4),
#  ('The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   1),
#  ("The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)",
#   1),
#  ('The Rest Is Noise: Listening to the Twentieth Century', 1),
#  ('The Red Tent', 5),
#  ('The Purest Hook (Second Circle Tattoos #3)', 1),
#  ('The Picture of Dorian Gray', 2),
#  ('The Obsession', 1),
#  ('The Nightingale', 4),
#  ('The Nanny Diaries (Nanny #1)', 5),
#  ('The Name of God is Mercy', 2),
#  ('The Maze Runner (The Maze Runner #1)', 1),
#  ("The Lover's Dictionary", 2),
#  ('The Lonely Ones', 5),
#  ('The Last Painting of Sara de Vos', 2),
#  ('The Land of 10,000 Madonnas', 4),
#  ('The Infinities', 1),
#  ("The Husband's Secret", 5),
#  ('The Guns of August', 2),
#  ('The Guernsey Literary and Potato Peel Pie Society', 1),
#  ('The Giver (The Giver Quartet #1)', 1),
#  ('The Girl Who Played with Fire (Millennium Trilogy #2)', 2),
#  ("The Girl Who Kicked the Hornet's Nest (Millennium Trilogy #3)", 1),
#  ('The End of Faith: Religion, Terror, and the Future of Reason', 4),
#  ('The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',
#   4),
#  ('The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements',
#   5),
#  ('The Devil Wears Prada (The Devil Wears Prada #1)', 1),
#  ('The Demon-Haunted World: Science as a Candle in the Dark', 4),
#  ('The Day the Crayons Came Home (Crayons)', 5),
#  ('The Da Vinci Code (Robert Langdon #2)', 2),
#  ("The Cuckoo's Calling (Cormoran Strike #1)", 1),
#  ('The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#   4),
#  ('The Complete Poems', 5),
#  ('The Catcher in the Rye', 1),
#  ('The Cat in the Hat (Beginner Books B-1)', 2),
#  ('The Case for Christ (Cases for Christianity)', 1),
#  ('The Book Thief', 2),
#  ('The Book of Basketball: The NBA According to The Sports Guy', 5),
#  ('The Blind Side: Evolution of a Game', 5),
#  ('The Autobiography of Malcolm X', 2),
#  ('The Art of Fielding', 1),
#  ("Surely You're Joking, Mr. Feynman!: Adventures of a Curious Character", 2),
#  ('Spilled Milk: Based on a True Story', 1),
#  ('Something Borrowed (Darcy & Rachel #1)', 5),
#  ('Something Blue (Darcy & Rachel #2)', 1),
#  ('Soldier (Talon #3)', 2),
#  ('Shopaholic & Baby (Shopaholic #5)', 2),
#  ('Seven Days in the Art World', 2),
#  ('Seven Brief Lessons on Physics', 4),
#  ('Scarlet (The Lunar Chronicles #2)', 4),
#  ("Sarah's Key", 1),
#  ('Saga, Volume 3 (Saga (Collected Editions) #3)', 5),
#  ('Running with Scissors', 4),
#  ('Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',
#   4),
#  ('Rework', 2),
#  ('Ready Player One', 4),
#  ("Quiet: The Power of Introverts in a World That Can't Stop Talking", 1),
#  ('Persepolis: The Story of a Childhood (Persepolis #1-2)', 1),
#  ('Packing for Mars: The Curious Science of Life in the Void', 2),
#  ('Outliers: The Story of Success', 1),
#  ('Orange Is the New Black', 2),
#  ('One for the Money (Stephanie Plum #1)', 2),
#  ('Notes from a Small Island (Notes From a Small Island #1)', 1),
#  ('Night (The Night Trilogy #1)', 1),
#  ('Morning Star (Red Rising #3)', 1),
#  ('Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing',
#   1),
#  ('Midnight Riot (Peter Grant/ Rivers of London - books #1)', 2),
#  ('Me Talk Pretty One Day', 2),
#  ('Manuscript Found in Accra', 2),
#  ('Lust & Wonder', 2),
#  ("Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)",
#   2),
#  ('Life Without a Recipe', 5),
#  ('Life After Life', 2),
#  ('Letter to a Christian Nation', 1),
#  ("Let's Pretend This Never Happened: A Mostly True Memoir", 1),
#  ('Legend (Legend #1)', 4),
#  ('Lean In: Women, Work, and the Will to Lead', 1),
#  ("Lamb: The Gospel According to Biff, Christ's Childhood Pal", 5),
#  ('Lady Renegades (Rebel Belle #3)', 5),
#  ('Jurassic Park (Jurassic Park #1)', 1),
#  ("It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond",
#   1),
#  ('Into the Wild', 5),
#  ('Inferno (Robert Langdon #4)', 5),
#  ('If I Run (If I Run #1)', 4),
#  ("I've Got Your Number", 1),
#  ('I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban',
#   2),
#  ('House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth',
#   2),
#  ('House of Leaves', 1),
#  ('Horrible Bear!', 2),
#  ('Holidays on Ice', 2),
#  ('Heir to the Sky', 4),
#  ('Green Eggs and Ham (Beginner Books B-16)', 4),
#  ('Grayson, Vol 3: Nemesis (Grayson #3)', 1),
#  ('Gratitude', 5),
#  ('Gone Girl', 5),
#  ('Golden (Heart of Dread #3)', 4),
#  ('Girl in the Blue Coat', 2),
#  ('Fruits Basket, Vol. 3 (Fruits Basket #3)', 2),
#  ('Fire Bound (Sea Haven/Sisters of the Heart #5)', 4),
#  ('Fifty Shades Freed (Fifty Shades #3)', 5),
#  ('Fellside', 1),
#  ('Eclipse (Twilight #3)', 1),
#  ('Dune (Dune #1)', 1),
#  ('Do Androids Dream of Electric Sheep? (Blade Runner #1)', 1),
#  ('Disrupted: My Misadventure in the Start-Up Bubble', 5),
#  ('Dead Wake: The Last Crossing of the Lusitania', 5),
#  ('David and Goliath: Underdogs, Misfits, and the Art of Battling Giants', 1),
#  ('Darkfever (Fever #1)', 1),
#  ('Dark Places', 5),
#  ('Crazy Rich Asians (Crazy Rich Asians #1)', 5),
#  ('Counting Thyme', 1),
#  ('Cosmos', 2),
#  ('Civilization and Its Discontents', 2),
#  ('Cinder (The Lunar Chronicles #1)', 1),
#  ("Catastrophic Happiness: Finding Joy in Childhood's Messy Years", 2),
#  ('Career of Evil (Cormoran Strike #3)', 2),
#  ('Breaking Dawn (Twilight #4)', 5),
#  ('Brave Enough', 5),
#  ('Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen',
#   2),
#  ('Blink: The Power of Thinking Without Thinking', 5),
#  ('Black Flags: The Rise of ISIS', 1),
#  ('Black Butler, Vol. 1 (Black Butler #1)', 1),
#  ('Big Little Lies', 1),
#  ('Between Shades of Gray', 5),
#  ("Best of My Love (Fool's Gold #20)", 2),
#  ('Beowulf', 2),
#  ('Beautiful Creatures (Caster Chronicles #1)', 5),
#  ('Awkward', 2),
#  ('Ash', 4),
#  ('Are We Smart Enough to Know How Smart Animals Are?', 1),
#  ('Annie on My Mind', 5),
#  ('And Then There Were None', 2),
#  ('A Walk in the Woods: Rediscovering America on the Appalachian Trail', 4),
#  ('A Visit from the Goon Squad', 5),
#  ('A Storm of Swords (A Song of Ice and Fire #3)', 2),
#  ('A Heartbreaking Work of Staggering Genius', 5),
#  ('8 Keys to Mental Health Through Exercise', 1),
#  ('#GIRLBOSS', 1),
#  ('The Suffragettes (Little Black Classics, #96)', 2),
#  ("The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)", 1),
#  ('Sugar Rush (Offensive Line #2)', 1),
#  ('Run, Spot, Run: The Ethics of Keeping Pets', 1),
#  ('New Moon (Twilight #2)', 4),
#  ('Life', 5),
#  ('H is for Hawk', 5),
#  ('Girl Online On Tour (Girl Online #2)', 1),
#  ('Fruits Basket, Vol. 2 (Fruits Basket #2)', 5),
#  ('Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#   4),
#  ('Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', 4),
#  ('While You Were Mine', 5),
#  ('Ways of Seeing', 5),
#  ('Vampire Knight, Vol. 1 (Vampire Knight #1)', 1),
#  ('Vampire Girl (Vampire Girl #1)', 2),
#  ('Twenty Love Poems and a Song of Despair', 4),
#  ('Travels with Charley: In Search of America', 5),
#  ('Three Wishes (River of Time: California #1)', 2),
#  ('This One Moment (Pushing Limits #1)', 1),
#  ('The Zombie Room', 5),
#  ('The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#   2),
#  ('The Tumor', 5),
#  ('The Story of Hong Gildong', 4),
#  ('The Silent Wife', 5),
#  ('The Selfish Gene', 1),
#  ("The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", 4),
#  ('The Nicomachean Ethics', 1),
#  ('The Mirror & the Maze (The Wrath and the Dawn #1.5)', 1),
#  ('The Little Prince', 2),
#  ('The Light of the Fireflies', 1),
#  ('The Last Girl (The Dominion Trilogy #1)', 2),
#  ('The Iliad', 1),
#  ('The Hook Up (Game On #1)', 5),
#  ('The Haters', 5),
#  ('The Girl You Lost', 5),
#  ('The End of the Jesus Era (An Investigation #1)', 1),
#  ('The Edge of Reason (Bridget Jones #2)', 4),
#  ('The Art of Not Breathing', 4),
#  ('Taking Shots (Assassins #1)', 2),
#  ('Shatter Me (Shatter Me #1)', 1),
#  ('Shadow Rites (Jane Yellowrock #10)', 4),
#  ('Settling the Score (The Summer Games #1)', 2),
#  ('Sense and Sensibility', 1),
#  ('Saga, Volume 1 (Saga (Collected Editions) #1)', 1),
#  ('Rhythm, Chord & Malykhin', 2),
#  ('Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   5),
#  ('Paradise Lost (Paradise #1)', 1),
#  ('Paper Girls, Vol. 1 (Paper Girls #1-5)', 4),
#  ('Origins (Alphas 0.5)', 1),
#  ('One Second (Seven #7)', 2),
#  ("Old Records Never Die: One Man's Quest for His Vinyl and His Past", 2),
#  ('Off Sides (Off #1)', 5),
#  ('Of Mice and Men', 2),
#  ('Myriad (Prentor #1)', 4),
#  ('My Perfect Mistake (Over the Top #1)', 2),
#  ('Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', 4),
#  ('Meditations', 2),
#  ('Matilda', 1),
#  ('Lost Among the Living', 4),
#  ('Kitchens of the Great Midwest', 5),
#  ('Jane Eyre', 5),
#  ('Imperfect Harmony', 4),
#  ('Icing (Aces Hockey #2)', 4),
#  ("Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", 4),
#  ('Giant Days, Vol. 1 (Giant Days #1-4)', 4),
#  ('Fruits Basket, Vol. 1 (Fruits Basket #1)', 5),
#  ('Frankenstein', 2),
#  ('Emma', 2),
#  ('Deep Under (Walker Security #1)', 5),
#  ("Choosing Our Religion: The Spiritual Lives of America's Nones", 4),
#  ("Charity's Cross (Charles Towne Belles #4)", 1),
#  ('Bright Lines', 5),
#  ("Bridget Jones's Diary (Bridget Jones #1)", 1),
#  ('Bounty (Colorado Mountain #7)', 4),
#  ('Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', 5),
#  ('Beyond Good and Evil', 1),
#  ("Alice in Wonderland (Alice's Adventures in Wonderland #1)", 1),
#  ('Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', 4),
#  ("A Spy's Devotion (The Regency Spies of London #1)", 5),
#  ("1st to Die (Women's Murder Club #1)", 1),
#  ('1,000 Places to See Before You Die', 5),
#  ('AroundEarth', 2),
#  ('America', 4),
#  ('harstreet', 1)]

# %%
ques4= cr.execute("SELECT bookname from book1000 WHERE (rate != 5  and rate !=2) and (price BETWEEN 10 and 50 )")
ques4.fetchall()
# Out:
# [('Sharp Objects',),
#  ('The Requiem Red',),
#  ('The Dirty Little Secrets of Getting Your Dream Job',),
#  ('The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',),
#  ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',),
#  ("Shakespeare's Sonnets",),
#  ('Olio',),
#  ('Mesaerion: The Best Science Fiction Stories 1800-1849',),
#  ('In Her Wake',),
#  ('Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',),
#  ("America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",),
#  ('Wall and Piece',),
#  ('The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',),
#  ('The Bear and the Piano',),
#  ('Penny Maybe',),
#  ('In a Dark, Dark Wood',),
#  ('When We Collided',),
#  ('Untitled Collection: Sabbath Poems 2014',),
#  ('Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',),
#  ('Unicorn Tracks',),
#  ('Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',),
#  ('Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',),
#  ('Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',),
#  ('This One Summer',),
#  ('The Torch Is Passed: A Harding Family Story',),
#  ('The Natural History of Us (The Fine Art of Pretending #2)',),
#  ('The Nameless City (The Nameless City #1)',),
#  ("The Most Perfect Thing: Inside (and Outside) a Bird's Egg",),
#  ('The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',),
#  ('The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',),
#  ('The Gutsy Girl: Escapades for Your Life of Epic Adventure',),
#  ('The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',),
#  ('The Art Forger',),
#  ('The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',),
#  ('Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',),
#  ('Saga, Volume 6 (Saga (Collected Editions) #6)',),
#  ('Pop Gun War, Volume 1: Gift',),
#  ('Patience',),
#  ('Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',),
#  ('orange: The Complete Collection 1 (orange: The Complete Collection #1)',),
#  ('Online Marketing for Busy Authors: A Step-By-Step Guide',),
#  ('On a Midnight Clear',),
#  ('Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',),
#  ('Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',),
#  ('Layered: Baking, Building, and Styling Spectacular Cakes',),
#  ('In the Country We Love: My Family Divided',),
#  ('How to Be Miserable: 40 Strategies You Already Use',),
#  ('Her Backup Boyfriend (The Sorensen Family #1)',),
#  ('Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',),
#  ('First and First (Five Boroughs #3)',),
#  ('Fifty Shades Darker (Fifty Shades #2)',),
#  ('Crown of Midnight (Throne of Glass #2)',),
#  ('Codename Baboushka, Volume 1: The Conclave of Death',),
#  ('Camp Midnight',),
#  ('Burning',),
#  ('Algorithms to Live By: The Computer Science of Human Decisions',),
#  ('A World of Flavor: Your Gluten Free Passport',),
#  ('A Murder in Time',),
#  ('A Fierce and Subtle Poison',),
#  ('You Are What You Love: The Spiritual Power of Habit',),
#  ("William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",),
#  ('Tracing Numbers on a Train',),
#  ('Throne of Glass (Throne of Glass #1)',),
#  ('The Wedding Dress',),
#  ('The Vacationers',),
#  ('The Stranger',),
#  ('The Shadow Hero (The Shadow Hero)',),
#  ('The Secret (The Secret #1)',),
#  ('The Project',),
#  ('The Murder of Roger Ackroyd (Hercule Poirot #4)',),
#  ('The Mistake (Off-Campus #2)',),
#  ('The Long Shadow of Small Ghosts: Murder and Memory in an American City',),
#  ('The Kite Runner',),
#  ('The House by the Lake',),
#  ('The Glittering Court (The Glittering Court #1)',),
#  ('The Genius of Birds',),
#  ('The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',),
#  ("The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",),
#  ('The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',),
#  ('Something More Than This',),
#  ('Shobu Samurai, Project Aryoku (#3)',),
#  ('Secrets and Lace (Fatal Hearts #1)',),
#  ('Romero and Juliet: A Tragic Tale of Love and Zombies',),
#  ('Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',),
#  ('Poems That Make Grown Women Cry',),
#  ('Nightingale, Sing',),
#  ('Night Sky with Exit Wounds',),
#  ('Miss Peregrineâ\x80\x99s Home for Peculiar Children (Miss Peregrineâ\x80\x99s Peculiar Children #1)',),
#  ('Little Red',),
#  ('Hollow City (Miss Peregrineâ\x80\x99s Peculiar Children #2)',),
#  ('Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',),
#  ('Follow You Home',),
#  ('First Steps for New Christians (Print Edition)',),
#  ('Fables, Vol. 1: Legends in Exile (Fables #1)',),
#  ('Drive: The Surprising Truth About What Motivates Us',),
#  ('Doing It Over (Most Likely To #1)',),
#  ('Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',),
#  ('Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',),
#  ('Close to You',),
#  ('Big Magic: Creative Living Beyond Fear',),
#  ('Anonymous',),
#  ('Amy Meets the Saints and Sages',),
#  ('Amid the Chaos',),
#  ('Zealot: The Life and Times of Jesus of Nazareth',),
#  ('Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',),
#  ('Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',),
#  ('V for Vendetta (V for Vendetta Complete)',),
#  ("The Wedding Pact (The O'Malleys #2)",),
#  ('The Power of Habit: Why We Do What We Do in Life and Business',),
#  ('The Marriage of Opposites',),
#  ('The Lucifer Effect: Understanding How Good People Turn Evil',),
#  ('The Long Haul (Diary of a Wimpy Kid #9)',),
#  ('The Loney',),
#  ('The Literature Book (Big Ideas Simply Explained)',),
#  ('The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',),
#  ('The First Hostage (J.B. Collins #2)',),
#  ('The Dovekeepers',),
#  ('The Bane Chronicles (The Bane Chronicles #1-11)',),
#  ('The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâ\x80\x99s Most Precious Manuscripts',),
#  ('The 14th Colony (Cotton Malone #11)',),
#  ('That Darkness (Gardiner and Renner #1)',),
#  ('Tastes Like Fear (DI Marnie Rome #3)',),
#  ('Take Me with You',),
#  ('Swell: A Year of Waves',),
#  ('Still Life with Bread Crumbs',),
#  ('Sorting the Beef from the Bull: The Science of Food Fraud Forensics',),
#  ('So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',),
#  ('See America: A Celebration of Our National Parks & Treasured Sites',),
#  ('salt.',),
#  ('Robin War',),
#  ('Rain Fish',),
#  ('Pet Sematary',),
#  ('My Name Is Lucy Barton',),
#  ('My Mrs. Brown',),
#  ('My Kind of Crazy',),
#  ('Mr. Mercedes (Bill Hodges Trilogy #1)',),
#  ('Luckiest Girl Alive',),
#  ('Love Is a Mix Tape (Music #1)',),
#  ('Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',),
#  ("It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",),
#  ('Island of Dragons (Unwanteds #7)',),
#  ("I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",),
#  ('I Am Pilgrim (Pilgrim #1)',),
#  ('Hush, Hush (Hush, Hush #1)',),
#  ('Hold Your Breath (Search and Rescue #1)',),
#  ('Glory over Everything: Beyond The Kitchen House',),
#  ('Feathers: Displays of Brilliant Plumage',),
#  ('Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',),
#  ('Every Last Word',),
#  ('Eligible (The Austen Project #4)',),
#  ('Eight Hundred Grapes',),
#  ('Daily Fantasy Sports',),
#  ('Cometh the Hour (The Clifton Chronicles #6)',),
#  ('Code Name Verity (Code Name Verity #1)',),
#  ('Clockwork Angel (The Infernal Devices #1)',),
#  ('City of Fallen Angels (The Mortal Instruments #4)',),
#  ('City of Bones (The Mortal Instruments #1)',),
#  ('City of Ashes (The Mortal Instruments #2)',),
#  ('Cell',),
#  ('Carry On, Warrior: Thoughts on Life Unarmed',),
#  ('Buying In: The Secret Dialogue Between What We Buy and Who We Are',),
#  ('Barefoot Contessa Back to Basics',),
#  ('Balloon Animals',),
#  ('Art Ops Vol. 1',),
#  ('A Man Called Ove',),
#  ('A Distant Mirror: The Calamitous 14th Century',),
#  ('1491: New Revelations of the Americas Before Columbus',),
#  ('The Three Searches, Meaning, and the Story',),
#  ('Searching for Meaning in Gailana',),
#  ('Rook',),
#  ('13 Hours: The Inside Account of What Really Happened In Benghazi',),
#  ("Will You Won't You Want Me?",),
#  ('Tipping Point for Planet Earth: How Close Are We to the Edge?',),
#  ('The Midnight Watch: A Novel of the Titanic and the Californian',),
#  ('The Golden Condom: And Other Essays on Love Lost and Found',),
#  ('The Children',),
#  ('Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',),
#  ('Raspberry Pi Electronics Projects for the Evil Genius',),
#  ('Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',),
#  ('Poisonous (Max Revere Novels #3)',),
#  ('One with You (Crossfire #5)',),
#  ('Most Wanted',),
#  ('Hide Away (Eve Duncan #20)',),
#  ('Furiously Happy: A Funny Book About Horrible Things',),
#  ('Dirty (Dive Bar #1)',),
#  ('Can You Keep a Secret? (Fear Street Relaunch #4)',),
#  ('A Paris Apartment',),
#  ('A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',),
#  ('The Sleep Revolution: Transforming Your Life, One Night at a Time',),
#  ('The Art of Startup Fundraising',),
#  ('Sleeping Giants (Themis Files #1)',),
#  ('Playing with Fire',),
#  ('Off the Hook (Fishing for Trouble #1)',),
#  ('M Train',),
#  ('Lies and Other Acts of Love',),
#  ('Lab Girl',),
#  ('Keep Me Posted',),
#  ('Grey (Fifty Shades #4)',),
#  ('Daredevils',),
#  ('Cravings: Recipes for What You Want to Eat',),
#  ('Arena',),
#  ("A Mother's Reckoning: Living in the Aftermath of Tragedy",),
#  ('11/22/63',),
#  ('The Shack',),
#  ('The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',),
#  ('The Book of Mormon',),
#  ('Nap-a-Roo',),
#  ('NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',),
#  ("If I Gave You God's Phone Number....: Searching for Spirituality in America",),
#  ('Fruits Basket, Vol. 9 (Fruits Basket #9)',),
#  ('Dress Your Family in Corduroy and Denim',),
#  ("Don't Forget Steven",),
#  ('Art and Fear: Observations on the Perils (and Rewards) of Artmaking',),
#  ('Zero to One: Notes on Startups, or How to Build the Future',),
#  ('Why Not Me?',),
#  ('The New Drawing on the Right Side of the Brain',),
#  ("The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",),
#  ('The Grownup',),
#  ("The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",),
#  ('South of Sunshine',),
#  ('Rising Strong',),
#  ('Please Kill Me: The Uncensored Oral History of Punk',),
#  ("Man's Search for Meaning",),
#  ('Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',),
#  ('Kierkegaard: A Christian Missionary to Christians',),
#  ('John Vassos: Industrial Design for Modern Life',),
#  ('I Will Find You',),
#  ('Hystopia: A Novel',),
#  ('History of Beauty',),
#  ("Ender's Game (The Ender Quintet #1)",),
#  ('Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World',),
#  ('Death by Leisure: A Cautionary Tale',),
#  ('Brilliant Beacons: A History of the American Lighthouse',),
#  ('A Murder Over a Girl: Justice, Gender, Junior High',),
#  ('You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',),
#  ('Under the Tuscan Sun',),
#  ("Toddlers Are A**holes: It's Not Your Fault",),
#  ("The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible",),
#  ('The Whale',),
#  ('The Story of Art',),
#  ('The Origin of Species',),
#  ('The Great Gatsby',),
#  ('The Good Girl',),
#  ('The Glass Castle',),
#  ("The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",),
#  ('The Drowning Girls',),
#  ('The Constant Princess (The Tudor Court #1)',),
#  ('The Bourne Identity (Jason Bourne #1)',),
#  ('The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',),
#  ('Sit, Stay, Love',),
#  ('Sister Dear',),
#  ('Playing from the Heart',),
#  ('Meternity',),
#  ('Memoirs of a Geisha',),
#  ('Life of Pi',),
#  ('How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',),
#  ('Fruits Basket, Vol. 7 (Fruits Basket #7)',),
#  ('For the Love: Fighting for Grace in a World of Impossible Standards',),
#  ('Delivering the Truth (Quaker Midwife Mystery #1)',),
#  ('Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',),
#  ('Benjamin Franklin: An American Life',),
#  ('A Gathering of Shadows (Shades of Magic #2)',),
#  ('The Mysterious Affair at Styles (Hercule Poirot #1)',),
#  ('The Joy of Cooking',),
#  ('The Invention of Wings',),
#  ('The Great Railway Bazaar',),
#  ('The Golden Compass (His Dark Materials #1)',),
#  ('The God Delusion',),
#  ('The Girl You Left Behind (The Girl You Left Behind #1)',),
#  ('Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',),
#  ('Pride and Prejudice',),
#  ('Musicophilia: Tales of Music and the Brain',),
#  ('Mere Christianity',),
#  ('Me Before You (Me Before You #1)',),
#  ('In Cold Blood',),
#  ('Girl, Interrupted',),
#  ('Fruits Basket, Vol. 6 (Fruits Basket #6)',),
#  ('Deception Point',),
#  ('Death Note, Vol. 6: Give-and-Take (Death Note #6)',),
#  ('Better Homes and Gardens New Cook Book',),
#  ('An Unquiet Mind: A Memoir of Moods and Madness',),
#  ('World Without End (The Pillars of the Earth #2)',),
#  ('Will Grayson, Will Grayson (Will Grayson, Will Grayson)',),
#  ('Where She Went (If I Stay #2)',),
#  ('Two Summers',),
#  ('This Is Your Brain on Music: The Science of a Human Obsession',),
#  ('The Secret Garden',),
#  ('The Metamorphosis',),
#  ('The Little Paris Bookshop',),
#  ('The Grand Design',),
#  ('The Firm',),
#  ('The Fault in Our Stars',),
#  ('The Dream Thieves (The Raven Cycle #2)',),
#  ('The Crossover',),
#  ('Tell the Wind and Fire',),
#  ('Tell Me Three Things',),
#  ("Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",),
#  ('Remember Me?',),
#  ('Red Dragon (Hannibal Lecter #1)',),
#  ('My Mother Was Nuts',),
#  ('Maybe Something Beautiful: How Art Transformed a Neighborhood',),
#  ('Lola and the Boy Next Door (Anna and the French Kiss #2)',),
#  ('Killing Floor (Jack Reacher #1)',),
#  ('Harry Potter and the Deathly Hallows (Harry Potter #7)',),
#  ('Fruits Basket, Vol. 5 (Fruits Basket #5)',),
#  ('Foundation (Foundation (Publication Order) #1)',),
#  ('Fool Me Once',),
#  ('Find Her (Detective D.D. Warren #8)',),
#  ('Evicted: Poverty and Profit in the American City',),
#  ('Data, A Love Story: How I Gamed Online Dating to Meet My Match',),
#  ('Critique of Pure Reason',),
#  ("A Girl's Guide to Moving On (New Beginnings #2)",),
#  ('A Feast for Crows (A Song of Ice and Fire #4)',),
#  ('A Clash of Kings (A Song of Ice and Fire #2)',),
#  ('The Shining (The Shining #1)',),
#  ('The Jazz of Physics: The Secret Link Between Music and the Structure of the Universe',),
#  ('The Gunning of America: Business and the Making of American Gun Culture',),
#  ('Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',),
#  ('Night Shift (Night Shift #1-20)',),
#  ('Needful Things',),
#  ('Mockingjay (The Hunger Games #3)',),
#  ('Little Women (Little Women #1)',),
#  ('It',),
#  ("Harry Potter and the Sorcerer's Stone (Harry Potter #1)",),
#  ('Harry Potter and the Prisoner of Azkaban (Harry Potter #3)',),
#  ('Harry Potter and the Order of the Phoenix (Harry Potter #5)',),
#  ('Harry Potter and the Chamber of Secrets (Harry Potter #2)',),
#  ('Gone with the Wind',),
#  ('God Is Not Great: How Religion Poisons Everything',),
#  ('Girl With a Pearl Earring',),
#  ('Dark Lover (Black Dagger Brotherhood #1)',),
#  ('Changing the Game (Play by Play #2)',),
#  ('Can You Keep a Secret?',),
#  ('A History of God: The 4,000-Year Quest of Judaism, Christianity, and Islam',),
#  ("'Salem's Lot",),
#  ('Zero History (Blue Ant #3)',),
#  ('Wuthering Heights',),
#  ('World War Z: An Oral History of the Zombie War',),
#  ('Wild: From Lost to Found on the Pacific Crest Trail',),
#  ("Where'd You Go, Bernadette",),
#  ("We the People: The Modern-Day Figures Who Have Reshaped and Affirmed the Founding Fathers' Vision of America",),
#  ('We Are All Completely Beside Ourselves',),
#  ('Walk the Edge (Thunder Road #2)',),
#  ('Under the Banner of Heaven: A Story of Violent Faith',),
#  ('Three-Martini Lunch',),
#  ('Thinking, Fast and Slow',),
#  ('The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)',),
#  ('The Undomestic Goddess',),
#  ('The Travelers',),
#  ('The Thing About Jellyfish',),
#  ('The Smitten Kitchen Cookbook',),
#  ('The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',),
#  ('The Rise of Theodore Roosevelt (Theodore Roosevelt #1)',),
#  ("The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)",),
#  ('The Rest Is Noise: Listening to the Twentieth Century',),
#  ('The Purpose Driven Life: What on Earth Am I Here for?',),
#  ('The Purest Hook (Second Circle Tattoos #3)',),
#  ('The Paris Wife',),
#  ('The Obsession',),
#  ('The Nightingale',),
#  ('The New Guy (and Other Senior Year Distractions)',),
#  ('The Maze Runner (The Maze Runner #1)',),
#  ("The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses",),
#  ('The Land of 10,000 Madonnas',),
#  ('The Infinities',),
#  ("The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)",),
#  ('The Guernsey Literary and Potato Peel Pie Society',),
#  ('The Goldfinch',),
#  ('The Giver (The Giver Quartet #1)',),
#  ('The Girl with All the Gifts',),
#  ('The Exiled',),
#  ('The End of Faith: Religion, Terror, and the Future of Reason',),
#  ('The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',),
#  ('The Devil Wears Prada (The Devil Wears Prada #1)',),
#  ("The Cuckoo's Calling (Cormoran Strike #1)",),
#  ('The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',),
#  ('The Catcher in the Rye',),
#  ('The Case for Christ (Cases for Christianity)',),
#  ('The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution',),
#  ('The Art of Fielding',),
#  ('Stiff: The Curious Lives of Human Cadavers',),
#  ('Spilled Milk: Based on a True Story',),
#  ('Seven Brief Lessons on Physics',),
#  ('Scarlet (The Lunar Chronicles #2)',),
#  ("Sarah's Key",),
#  ('Running with Scissors',),
#  ('Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',),
#  ('Reservations for Two',),
#  ('Red: The True Story of Red Riding Hood',),
#  ('Ready Player One',),
#  ("Quiet: The Power of Introverts in a World That Can't Stop Talking",),
#  ('Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',),
#  ('Persepolis: The Story of a Childhood (Persepolis #1-2)',),
#  ('Outliers: The Story of Success',),
#  ('Original Fake',),
#  ('Notes from a Small Island (Notes From a Small Island #1)',),
#  ('Night (The Night Trilogy #1)',),
#  ('Neither Here nor There: Travels in Europe',),
#  ('Naked',),
#  ('Morning Star (Red Rising #3)',),
#  ('Lila (Gilead #3)',),
#  ('Letter to a Christian Nation',),
#  ("Let's Pretend This Never Happened: A Mostly True Memoir",),
#  ('Legend (Legend #1)',),
#  ('Lean In: Women, Work, and the Will to Lead',),
#  ('Jurassic Park (Jurassic Park #1)',),
#  ("It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond",),
#  ('Is Everyone Hanging Out Without Me? (And Other Concerns)',),
#  ("In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin",),
#  ('If I Run (If I Run #1)',),
#  ("I've Got Your Number",),
#  ('Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',),
#  ('Heir to the Sky',),
#  ('Green Eggs and Ham (Beginner Books B-16)',),
#  ('Grayson, Vol 3: Nemesis (Grayson #3)',),
#  ('Golden (Heart of Dread #3)',),
#  ('Fire Bound (Sea Haven/Sisters of the Heart #5)',),
#  ('Fellside',),
#  ('Extreme Prey (Lucas Davenport #26)',),
#  ('Eragon (The Inheritance Cycle #1)',),
#  ('Eclipse (Twilight #3)',),
#  ('David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',),
#  ('Counting Thyme',),
#  ('Cinder (The Lunar Chronicles #1)',),
#  ('Boy Meets Boy',),
#  ('Black Flags: The Rise of ISIS',),
#  ('Black Butler, Vol. 1 (Black Butler #1)',),
#  ('Big Little Lies',),
#  ('Ash',),
#  ('Are We There Yet?',),
#  ('A Walk in the Woods: Rediscovering America on the Appalachian Trail',),
#  ('8 Keys to Mental Health Through Exercise',),
#  ('The Sense of an Ending',),
#  ('The Course of Love',),
#  ('Sugar Rush (Offensive Line #2)',),
#  ('Saga, Volume 2 (Saga (Collected Editions) #2)',),
#  ('Run, Spot, Run: The Ethics of Keeping Pets',),
#  ('New Moon (Twilight #2)',),
#  ("Kindle Paperwhite User's Guide",),
#  ('Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',),
#  ('Where Lightning Strikes (Bleeding Stars #3)',),
#  ('Vampire Knight, Vol. 1 (Vampire Knight #1)',),
#  ('Twenty Love Poems and a Song of Despair',),
#  ('This One Moment (Pushing Limits #1)',),
#  ('The Story of Hong Gildong',),
#  ('The Silent Twin (Detective Jennifer Knight #3)',),
#  ('The Selfish Gene',),
#  ('The Secret Healer',),
#  ('The Republic',),
#  ('The Odyssey',),
#  ('The Nicomachean Ethics',),
#  ('The Mirror & the Maze (The Wrath and the Dawn #1.5)',),
#  ('The Iliad',),
#  ('The Girl In The Ice (DCI Erika Foster #1)',),
#  ('The End of the Jesus Era (An Investigation #1)',),
#  ('The Edge of Reason (Bridget Jones #2)',),
#  ('The Complete Maus (Maus #1-2)',),
#  ('The Communist Manifesto',),
#  ('The Bette Davis Club',),
#  ('The Art of Not Breathing',),
#  ('Starlark',),
#  ('Skip Beat!, Vol. 01 (Skip Beat! #1)',),
#  ('Sister Sable (The Mad Queen #1)',),
#  ('Shatter Me (Shatter Me #1)',),
#  ('Shadow Rites (Jane Yellowrock #10)',),
#  ('Sense and Sensibility',),
#  ('Saga, Volume 1 (Saga (Collected Editions) #1)',),
#  ('Paradise Lost (Paradise #1)',),
#  ('Paper Girls, Vol. 1 (Paper Girls #1-5)',),
#  ('Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',),
#  ('Origins (Alphas 0.5)',),
#  ('On the Road (Duluoz Legend)',),
#  ('Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',),
#  ('Matilda',),
#  ('Lost Among the Living',),
#  ('Lord of the Flies',),
#  ('Imperfect Harmony',),
#  ('Icing (Aces Hockey #2)',),
#  ('Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',),
#  ("Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",),
#  ('Forever Rockers (The Rocker #12)',),
#  ('Fighting Fate (Fighting #6)',),
#  ("Choosing Our Religion: The Spiritual Lives of America's Nones",),
#  ('Charlie and the Chocolate Factory (Charlie Bucket #1)',),
#  ("Charity's Cross (Charles Towne Belles #4)",),
#  ("Bridget Jones's Diary (Bridget Jones #1)",),
#  ('Bounty (Colorado Mountain #7)',),
#  ('Blood Defense (Samantha Brinkman #1)',),
#  ('Beyond Good and Evil',),
#  ('worldend',),
#  ('America',),
#  ('catchme',),
#  ('harstreet',)]

# %%
ques5= cr.execute("SELECT bookname , price ,rate FROM book1000 order by price DESC LIMIT 5 ")
ques5.fetchall()
# Out:
# [('The Perfect Play (Play by Play #1)', 59.99, 3),
#  ('Last One Home (New Beginnings #1)', 59.98, 3),
#  ('Civilization and Its Discontents', 59.95, 2),
#  ('The Barefoot Contessa Cookbook', 59.92, 5),
#  ('The Diary of a Young Girl', 59.9, 3)]

# %%
ques6= cr.execute("SELECT bookname FROM book1000 order by rate desc , price ASC limit 30")
ques6.fetchall()[20:]
# Out:
# [('The Epidemic (The Program 0.6)',),
#  ('Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',),
#  ("A Gentleman's Position (Society of Gentlemen #3)",),
#  ('Disrupted: My Misadventure in the Start-Up Bubble',),
#  ('Fifty Shades Freed (Fifty Shades #3)',),
#  ('Batman: The Dark Knight Returns (Batman)',),
#  ('The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',),
#  ('Kill the Boy Band',),
#  ("Sophie's World",),
#  ('Shiver (The Wolves of Mercy Falls #1)',)]

# %%
cr.execute("insert into categoriess (category,bookid) VALUES('Suspens' , 1001)")
cr.execute("insert into book1000 (bookid,bookname,price,rate) VALUES('1001','AroundEarth','45','2')")
cr.execute("insert into book1000 (bookid,bookname,price,rate) VALUES (1002,'worldend',45.5,3)")
cr.execute("insert into book1000 (bookid,bookname,price,rate) VALUES (1003,'America',44,4)")
cr.execute("insert into book1000 (bookid,bookname,price,rate) VALUES (1004,'catchme',49.5,3)")
cr.execute("insert into book1000 (bookid,bookname,price,rate) VALUES (1005,'harstreet',40,1)")
db.commit()

# %%
ques8= cr.execute("UPDATE book1000 SET rate = '3' WHERE price <20")
ques8.fetchall()

# %%
ques9 = cr.execute("delete from book1000 where  price > 50 and rate <= 2")
ques9.fetchall()

# %%
ques10 = cr.execute("SELECT count(bookname),bookname FROM book1000 where bookname like '%Secret%' and price BETWEEN 10 and 25")
ques10.fetchall()
# Out:
# [(5, 'Secrets and Lace (Fatal Hearts #1)')]

# %%
ques11 = cr.execute("SELECT max(price)as price ,bookname FROM book1000 where rate = 5 ")
ques11.fetchall()[0]
# Out:
# (59.92, 'The Barefoot Contessa Cookbook')

# %%
ques12 = cr.execute("SELECT min(price) as price ,bookname FROM book1000 where rate = 5 ")
ques12.fetchall()[0]
# Out:
# (10, 'An Abundance of Katherines')

# %%
ques13 = cr.execute("SELECT avg(price) as averag  FROM book1000 where rate = 5")
ques13.fetchall()[0][0]
# Out:
# [(35.374489795918365,)]

# %%
ques14 = cr.execute("SELECT sum(price) FROM book1000 where rate = 2 and price BETWEEN 10 and 40")
ques14.fetchall()[0][0]
# Out:
# [(3310.4399999999987,)]

# %%
ques15 = cr.execute("select book1000.bookname, book1000.price ,book1000.rate ,categoriess.category from book1000 INNER JOIN categoriess on categoriess.bookid  = book1000.bookid ")
ques15.fetchall()
# Out:
# [('A Light in the Attic', 51.77, 3, 'Poetry'),
#  ('Tipping the Velvet', 53.74, 1, 'Historical Fiction'),
#  ('Soumission', 50.1, 1, 'Fiction'),
#  ('Sharp Objects', 47.82, 4, 'Mystery'),
#  ('Sapiens: A Brief History of Humankind', 54.23, 5, 'History'),
#  ('The Requiem Red', 22.65, 1, 'Young Adult'),
#  ('The Dirty Little Secrets of Getting Your Dream Job', 33.34, 4, 'Business'),
#  ('The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   17.93,
#   3,
#   'Default'),
#  ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   22.6,
#   4,
#   'Default'),
#  ('The Black Maria', 52.15, 1, 'Poetry'),
#  ('Starving Hearts (Triangular Trade Trilogy, #1)', 13.99, 2, 'Default'),
#  ("Shakespeare's Sonnets", 20.66, 4, 'Poetry'),
#  ('Set Me Free', 17.46, 5, 'Young Adult'),
#  ("Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   52.29,
#   5,
#   'Sequential Art'),
#  ('Rip it Up and Start Again', 35.02, 5, 'Music'),
#  ('Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   57.25,
#   3,
#   'Music'),
#  ('Olio', 23.88, 1, 'Poetry'),
#  ('Mesaerion: The Best Science Fiction Stories 1800-1849',
#   37.59,
#   1,
#   'Science Fiction'),
#  ('Libertarianism for Beginners', 51.33, 2, 'Politics'),
#  ("It's Only the Himalayas", 45.17, 2, 'Travel'),
#  ('In Her Wake', 12.84, 1, 'Thriller'),
#  ('How Music Works', 37.32, 2, 'Music'),
#  ('Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#   30.52,
#   3,
#   'Food and Drink'),
#  ('Chase Me (Paris Nights #2)', 25.27, 5, 'Romance'),
#  ('Black Dust', 34.53, 5, 'Romance'),
#  ('Birdsong: A Story in Pictures', 54.64, 3, 'Childrens'),
#  ("America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   22.5,
#   3,
#   'Default'),
#  ('Aladdin and His Wonderful Lamp', 53.13, 3, 'Default'),
#  ('Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe',
#   40.3,
#   5,
#   'Nonfiction'),
#  ('Wall and Piece', 44.18, 4, 'Art'),
#  ('The Four Agreements: A Practical Guide to Personal Freedom',
#   17.66,
#   5,
#   'Spirituality'),
#  ('The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#   31.05,
#   3,
#   'Nonfiction'),
#  ('The Elephant Tree', 23.82, 5, 'Thriller'),
#  ('The Bear and the Piano', 36.89, 1, 'Childrens'),
#  ("Sophie's World", 15.94, 5, 'Philosophy'),
#  ('Penny Maybe', 33.29, 3, 'Default'),
#  ('Maude (1883-1993):She Grew Up with the country', 18.02, 2, 'Default'),
#  ('In a Dark, Dark Wood', 19.63, 1, 'Mystery'),
#  ('Behind Closed Doors', 52.22, 4, 'Thriller'),
#  ("You can't bury them all: Poems", 33.63, 2, 'Poetry'),
#  ('Slow States of Collapse: Poems', 57.31, 3, 'Poetry'),
#  ('Reasons to Stay Alive', 26.41, 2, 'Nonfiction'),
#  ('Private Paris (Private #10)', 47.61, 5, 'Fiction'),
#  ('#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   23.11,
#   5,
#   'Nonfiction'),
#  ('Without Borders (Wanderlove #1)', 45.07, 2, 'New Adult'),
#  ('When We Collided', 31.77, 1, 'Contemporary'),
#  ('We Love You, Charlie Freeman', 50.27, 5, 'Fiction'),
#  ('Untitled Collection: Sabbath Poems 2014', 14.27, 4, 'Poetry'),
#  ('Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   44.18,
#   4,
#   'Nonfiction'),
#  ('Unicorn Tracks', 18.78, 3, 'Fantasy'),
#  ('Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   25.52,
#   1,
#   'History'),
#  ('Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   16.28,
#   1,
#   'Sequential Art'),
#  ('Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#   31.12,
#   3,
#   'Nonfiction'),
#  ('This One Summer', 19.49, 4, 'Sequential Art'),
#  ('Thirst', 17.27, 5, 'Fiction'),
#  ('The Torch Is Passed: A Harding Family Story', 19.09, 1, 'Add a comment'),
#  ('The Secret of Dreadwillow Carse', 56.13, 1, 'Childrens'),
#  ('The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#   56.41,
#   1,
#   'Food and Drink'),
#  ('The Past Never Ends', 56.5, 4, 'Mystery'),
#  ('The Natural History of Us (The Fine Art of Pretending #2)',
#   45.22,
#   3,
#   'Young Adult'),
#  ('The Nameless City (The Nameless City #1)', 38.16, 4, 'Sequential Art'),
#  ('The Murder That Never Was (Forensic Instincts #5)', 54.11, 3, 'Fiction'),
#  ("The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#   42.96,
#   4,
#   'Science'),
#  ('The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   23.89,
#   4,
#   'Add a comment'),
#  ('The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   16.77,
#   3,
#   'Nonfiction'),
#  ('The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   20.59,
#   5,
#   'Default'),
#  ('The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   37.13,
#   1,
#   'Nonfiction'),
#  ('The Electric Pencil: Drawings from Inside State Hospital No. 3',
#   56.06,
#   1,
#   'Nonfiction'),
#  ('The Death of Humanity: and the Case for Life', 58.11, 4, 'Philosophy'),
#  ('The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#   49.05,
#   3,
#   'Health'),
#  ('The Art Forger', 40.76, 3, 'Add a comment'),
#  ('The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   19.73,
#   1,
#   'History'),
#  ("The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   32.24,
#   5,
#   'Spirituality'),
#  ('Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   41.83,
#   4,
#   'Nonfiction'),
#  ('Soul Reader', 39.58, 2, 'Default'),
#  ('Security', 39.25, 2, 'Horror'),
#  ('Saga, Volume 6 (Saga (Collected Editions) #6)', 25.02, 3, 'Fantasy'),
#  ('Saga, Volume 5 (Saga (Collected Editions) #5)', 51.04, 2, 'Sequential Art'),
#  ('Reskilling America: Learning to Labor in the Twenty-First Century',
#   19.83,
#   2,
#   'Nonfiction'),
#  ('Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#   50.4,
#   3,
#   'Sequential Art'),
#  ('Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   13.61,
#   5,
#   'Sequential Art'),
#  ('Princess Between Worlds (Wide-Awake Princess #5)', 13.34, 5, 'Fantasy'),
#  ('Pop Gun War, Volume 1: Gift', 18.97, 1, 'Sequential Art'),
#  ('Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   36.28,
#   2,
#   'History'),
#  ('Patience', 10.16, 3, 'Sequential Art'),
#  ('Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   15.44,
#   4,
#   'Sequential Art'),
#  ('orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   48.41,
#   1,
#   'Sequential Art'),
#  ('Online Marketing for Busy Authors: A Step-By-Step Guide',
#   46.35,
#   1,
#   'Self Help'),
#  ('On a Midnight Clear', 14.07, 3, 'Add a comment'),
#  ('Obsidian (Lux #1)', 14.86, 2, 'Young Adult'),
#  ('My Paris Kitchen: Recipes and Stories', 33.37, 2, 'Food and Drink'),
#  ('Masks and Shadows', 56.4, 2, 'Fantasy'),
#  ('Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   14.02,
#   4,
#   'Food and Drink'),
#  ('Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   46.91,
#   2,
#   'Sequential Art'),
#  ('Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   45.61,
#   3,
#   'Sequential Art'),
#  ('Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   19.92,
#   2,
#   'Sequential Art'),
#  ('Layered: Baking, Building, and Styling Spectacular Cakes',
#   40.11,
#   1,
#   'Food and Drink'),
#  ('Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
#   53.9,
#   2,
#   'Add a comment'),
#  ('Join', 35.67, 5, 'Science Fiction'),
#  ('In the Country We Love: My Family Divided', 22, 4, 'Nonfiction'),
#  ('Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#   57.36,
#   5,
#   'Science'),
#  ('I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   29.17,
#   2,
#   'Sequential Art'),
#  ('I am a Hero Omnibus Volume 1', 54.63, 3, 'Sequential Art'),
#  ('How to Be Miserable: 40 Strategies You Already Use', 46.03, 1, 'Self Help'),
#  ('Her Backup Boyfriend (The Sorensen Family #1)', 33.97, 1, 'Romance'),
#  ('Giant Days, Vol. 2 (Giant Days #5-8)', 22.11, 2, 'Sequential Art'),
#  ('Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   29.69,
#   3,
#   'Historical Fiction'),
#  ('First and First (Five Boroughs #3)', 15.97, 4, 'Romance'),
#  ('Fifty Shades Darker (Fifty Shades #2)', 21.96, 1, 'Romance'),
#  ('Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#   54.35,
#   2,
#   'Nonfiction'),
#  ("Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#   37.97,
#   2,
#   'Religion'),
#  ('Danganronpa Volume 1', 51.99, 4, 'Sequential Art'),
#  ('Crown of Midnight (Throne of Glass #2)', 43.29, 3, 'Fantasy'),
#  ('Codename Baboushka, Volume 1: The Conclave of Death',
#   36.72,
#   4,
#   'Sequential Art'),
#  ('Camp Midnight', 17.08, 4, 'Sequential Art'),
#  ('Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   29.14,
#   5,
#   'Nonfiction'),
#  ('Burning', 28.81, 3, 'Young Adult'),
#  ('Bossypants', 49.46, 2, 'Default'),
#  ('Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   37.92,
#   2,
#   'Sequential Art'),
#  ('Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#   28.09,
#   2,
#   'Fantasy'),
#  ('Algorithms to Live By: The Computer Science of Human Decisions',
#   30.81,
#   1,
#   'Nonfiction'),
#  ('A World of Flavor: Your Gluten Free Passport', 42.95, 1, 'Default'),
#  ('A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#   56.76,
#   5,
#   'Default'),
#  ('A Murder in Time', 16.64, 1, 'Mystery'),
#  ('A Flight of Arrows (The Pathfinders #2)', 55.53, 5, 'Historical Fiction'),
#  ('A Fierce and Subtle Poison', 28.13, 4, 'Young Adult'),
#  ('A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#   52.37,
#   1,
#   'Fantasy'),
#  ('(Un)Qualified: How God Uses Broken People to Do Big Things',
#   54,
#   5,
#   'Christian'),
#  ('You Are What You Love: The Spiritual Power of Habit', 21.87, 4, 'Religion'),
#  ("William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#   43.3,
#   4,
#   'Science Fiction'),
#  ('Tuesday Nights in 1980', 21.04, 2, 'Fiction'),
#  ('Tracing Numbers on a Train', 41.6, 3, 'Default'),
#  ('Throne of Glass (Throne of Glass #1)', 35.07, 3, 'Fantasy'),
#  ('Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#   59.64,
#   1,
#   'History'),
#  ('Thirteen Reasons Why', 52.72, 1, 'Default'),
#  ('The White Cat and the Monk: A Retelling of the Poem â\x80\x9cPangur BÃ¡nâ\x80\x9d',
#   58.08,
#   4,
#   'Childrens'),
#  ('The Wedding Dress', 24.12, 1, 'Romance'),
#  ('The Vacationers', 42.15, 4, 'Fiction'),
#  ('The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future',
#   12.61,
#   5,
#   'Business'),
#  ('The Stranger', 17.44, 4, 'Philosophy'),
#  ('The Shadow Hero (The Shadow Hero)', 33.14, 1, 'Sequential Art'),
#  ('The Secret (The Secret #1)', 27.37, 4, 'Default'),
#  ('The Regional Office Is Under Attack!', 51.36, 5, 'Fiction'),
#  ('The Psychopath Test: A Journey Through the Madness Industry',
#   36,
#   2,
#   'Default'),
#  ('The Project', 10.65, 1, 'Science Fiction'),
#  ('The Power of Now: A Guide to Spiritual Enlightenment',
#   43.54,
#   2,
#   'Nonfiction'),
#  ("The Omnivore's Dilemma: A Natural History of Four Meals",
#   38.21,
#   2,
#   'Nonfiction'),
#  ('The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   37.34,
#   5,
#   'Food and Drink'),
#  ('The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 4, 'Mystery'),
#  ('The Mistake (Off-Campus #2)', 43.29, 3, 'New Adult'),
#  ("The Matchmaker's Playbook (Wingmen Inc. #1)", 55.85, 1, 'New Adult'),
#  ('The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   37.6,
#   2,
#   'Food and Drink'),
#  ('The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   10.97,
#   1,
#   'Crime'),
#  ('The Kite Runner', 41.82, 4, 'Default'),
#  ('The House by the Lake', 36.95, 1, 'Historical Fiction'),
#  ('The Glittering Court (The Glittering Court #1)', 44.28, 1, 'Fantasy'),
#  ('The Girl on the Train', 55.02, 2, 'Default'),
#  ('The Genius of Birds', 17.24, 1, 'Nonfiction'),
#  ('The Emerald Mystery', 23.15, 2, 'Default'),
#  ('The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   41.25,
#   1,
#   'Food and Drink'),
#  ("The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#   32,
#   3,
#   'Default'),
#  ("The Artist's Way: A Spiritual Path to Higher Creativity",
#   38.49,
#   5,
#   'Nonfiction'),
#  ('The Art of War', 33.34, 5, 'Default'),
#  ('The Argonauts', 10.93, 2, 'Autobiography'),
#  ('The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   27.55,
#   3,
#   'Business'),
#  ('Suddenly in Love (Lake Haven #1)', 55.99, 2, 'Romance'),
#  ('Something More Than This', 16.24, 4, 'Romance'),
#  ('Soft Apocalypse', 26.12, 2, 'Science Fiction'),
#  ("So You've Been Publicly Shamed", 12.23, 2, 'Nonfiction'),
#  ('Shoe Dog: A Memoir by the Creator of NIKE', 23.99, 2, 'Business'),
#  ('Shobu Samurai, Project Aryoku (#3)', 29.06, 3, 'Add a comment'),
#  ('Secrets and Lace (Fatal Hearts #1)', 20.27, 1, 'Default'),
#  ('Scarlett Epstein Hates It Here', 43.55, 5, 'Young Adult'),
#  ('Romero and Juliet: A Tragic Tale of Love and Zombies', 36.94, 1, 'Default'),
#  ('Redeeming Love', 20.47, 5, 'Christian Fiction'),
#  ('Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#   41.06,
#   1,
#   'Default'),
#  ('Poems That Make Grown Women Cry', 14.19, 4, 'Poetry'),
#  ('Nightingale, Sing', 38.28, 1, 'Young Adult'),
#  ('Night Sky with Exit Wounds', 41.05, 1, 'Poetry'),
#  ('Mrs. Houdini', 30.25, 5, 'Historical Fiction'),
#  ('Modern Romance', 28.26, 5, 'Add a comment'),
#  ('Miss Peregrineâ\x80\x99s Home for Peculiar Children (Miss Peregrineâ\x80\x99s Peculiar Children #1)',
#   10.76,
#   1,
#   'Default'),
#  ('Louisa: The Extraordinary Life of Mrs. Adams', 16.85, 2, 'Biography'),
#  ('Little Red', 13.47, 3, 'Childrens'),
#  ('Library of Souls (Miss Peregrineâ\x80\x99s Peculiar Children #3)',
#   48.56,
#   5,
#   'Young Adult'),
#  ('Large Print Heart of the Pride', 19.15, 2, 'Default'),
#  ('I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   57.36,
#   4,
#   'Womens Fiction'),
#  ('Hollow City (Miss Peregrineâ\x80\x99s Peculiar Children #2)',
#   42.98,
#   1,
#   'Fantasy'),
#  ('Grumbles', 22.16, 2, 'Default'),
#  ('Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   49.43,
#   4,
#   'Travel'),
#  ('Frostbite (Vampire Academy #2)', 29.99, 5, 'Young Adult'),
#  ('Follow You Home', 21.36, 1, 'Horror'),
#  ('First Steps for New Christians (Print Edition)', 29, 1, 'Default'),
#  ('Finders Keepers (Bill Hodges Trilogy #2)', 53.53, 5, 'Fiction'),
#  ('Fables, Vol. 1: Legends in Exile (Fables #1)', 41.62, 4, 'Sequential Art'),
#  ('Eureka Trivia 6.0', 54.59, 4, 'Default'),
#  ('Drive: The Surprising Truth About What Motivates Us', 34.95, 4, 'Default'),
#  ('Done Rubbed Out (Reightman & Bailey #1)', 37.72, 5, 'Default'),
#  ('Doing It Over (Most Likely To #1)', 35.61, 3, 'Romance'),
#  ('Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#   42.16,
#   3,
#   'Food and Drink'),
#  ('Dark Notes', 19.19, 5, 'Erotica'),
#  ('Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   19.43,
#   3,
#   'Nonfiction'),
#  ('Close to You', 49.46, 4, 'Christian Fiction'),
#  ('Chasing Heaven: What Dying Taught Me About Living',
#   37.8,
#   2,
#   'Spirituality'),
#  ('Big Magic: Creative Living Beyond Fear', 30.8, 3, 'Nonfiction'),
#  ('Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   27.43,
#   2,
#   'Nonfiction'),
#  ('Beauty Restored (Riley Family Legacy Novellas #3)', 11.11, 2, 'Default'),
#  ('Batman: The Long Halloween (Batman)', 36.5, 2, 'Sequential Art'),
#  ('Batman: The Dark Knight Returns (Batman)', 15.38, 5, 'Sequential Art'),
#  ("Ayumi's Violin", 15.48, 2, 'Default'),
#  ('Anonymous', 46.82, 4, 'Default'),
#  ('Amy Meets the Saints and Sages', 18.46, 3, 'Default'),
#  ('Amid the Chaos', 36.58, 1, 'Cultural'),
#  ('Amatus', 50.54, 5, 'Default'),
#  ('Agnostic: A Spirited Manifesto', 12.51, 5, 'Nonfiction'),
#  ('Zealot: The Life and Times of Jesus of Nazareth', 24.7, 3, 'History'),
#  ('You (You #1)', 43.61, 5, 'Thriller'),
#  ('Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   37.34,
#   4,
#   'Sequential Art'),
#  ('Wild Swans', 14.36, 2, 'Young Adult'),
#  ('Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   52.65,
#   4,
#   'Politics'),
#  ('Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   38.2,
#   4,
#   'Nonfiction'),
#  ("What's It Like in Space?: Stories from Astronauts Who've Been There",
#   19.6,
#   2,
#   'Nonfiction'),
#  ('We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#   53.9,
#   1,
#   'Sequential Art'),
#  ("Walt Disney's Alice in Wonderland", 12.96, 5, 'Childrens'),
#  ('V for Vendetta (V for Vendetta Complete)', 37.1, 4, 'Default'),
#  ('Until Friday Night (The Field Party #1)', 46.31, 2, 'Young Adult'),
#  ('Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#   45.95,
#   2,
#   'Default'),
#  ('Twenty Yawns', 22.08, 2, 'Childrens'),
#  ('Through the Woods', 25.38, 2, 'Sequential Art'),
#  ('This Is Where It Ends', 27.12, 2, 'Young Adult'),
#  ('The Year of Magical Thinking', 43.04, 2, 'Nonfiction'),
#  ('The Wright Brothers', 56.8, 4, 'Default'),
#  ("The White Queen (The Cousins' War #1)", 25.91, 5, 'Add a comment'),
#  ("The Wedding Pact (The O'Malleys #2)", 32.61, 3, 'Romance'),
#  ('The Time Keeper', 27.88, 5, 'Fiction'),
#  ('The Testament of Mary', 52.67, 4, 'Fiction'),
#  ('The Star-Touched Queen', 46.02, 5, 'Fantasy'),
#  ('The Songs of the Gods', 44.48, 5, 'Default'),
#  ('The Song of Achilles', 37.4, 5, 'Add a comment'),
#  ('The Rosie Project (Don Tillman #1)', 54.04, 1, 'Default'),
#  ('The Power of Habit: Why We Do What We Do in Life and Business',
#   16.88,
#   3,
#   'Default'),
#  ('The Marriage of Opposites', 28.08, 4, 'Historical Fiction'),
#  ('The Lucifer Effect: Understanding How Good People Turn Evil',
#   10.4,
#   1,
#   'Psychology'),
#  ('The Long Haul (Diary of a Wimpy Kid #9)', 44.07, 1, 'Humor'),
#  ('The Loney', 23.4, 1, 'Horror'),
#  ('The Literature Book (Big Ideas Simply Explained)', 17.43, 3, 'Nonfiction'),
#  ('The Last Mile (Amos Decker #2)', 54.21, 2, 'Mystery'),
#  ('The Immortal Life of Henrietta Lacks', 40.67, 2, 'Add a comment'),
#  ('The Hidden Oracle (The Trials of Apollo #1)', 52.26, 2, 'Fantasy'),
#  ('The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',
#   28.77,
#   3,
#   'Food and Drink'),
#  ('The Guilty (Will Robie #4)', 13.82, 2, 'Thriller'),
#  ('The First Hostage (J.B. Collins #2)', 25.85, 3, 'Fiction'),
#  ('The Dovekeepers', 48.78, 1, 'Add a comment'),
#  ('The Darkest Lie', 35.35, 5, 'Young Adult'),
#  ('The Bane Chronicles (The Bane Chronicles #1-11)', 44.73, 4, 'Fantasy'),
#  ('The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâ\x80\x99s Most Precious Manuscripts',
#   15.77,
#   1,
#   'Nonfiction'),
#  ('The 14th Colony (Cotton Malone #11)', 39.24, 1, 'Thriller'),
#  ('That Darkness (Gardiner and Renner #1)', 13.92, 1, 'Mystery'),
#  ('Tastes Like Fear (DI Marnie Rome #3)', 10.69, 1, 'Mystery'),
#  ('Take Me with You', 45.21, 3, 'Fiction'),
#  ('Swell: A Year of Waves', 45.58, 1, 'Nonfiction'),
#  ('Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   11.89,
#   5,
#   'Sequential Art'),
#  ('Still Life with Bread Crumbs', 26.41, 3, 'Fiction'),
#  ('Steve Jobs', 39.5, 5, 'Default'),
#  ('Sorting the Beef from the Bull: The Science of Food Fraud Forensics',
#   44.74,
#   4,
#   'Science'),
#  ('Someone Like You (The Harrisons #2)', 52.79, 5, 'Contemporary'),
#  ('So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   35.43,
#   4,
#   'Sequential Art'),
#  ('Shtum', 55.84, 4, 'Fiction'),
#  ('See America: A Celebration of Our National Parks & Treasured Sites',
#   48.87,
#   3,
#   'Travel'),
#  ('salt.', 46.78, 4, 'Poetry'),
#  ('Robin War', 47.82, 3, 'Sequential Art'),
#  ('Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#   25.48,
#   2,
#   'Sequential Art'),
#  ('Rain Fish', 23.57, 3, 'Childrens'),
#  ('Quarter Life Poetry: Poems for the Young, Broke and Hangry',
#   50.89,
#   5,
#   'Poetry'),
#  ('Pet Sematary', 10.56, 3, 'Horror'),
#  ('Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',
#   52.15,
#   3,
#   'Self Help'),
#  ('Once Was a Time', 18.28, 2, 'Childrens'),
#  ('Old School (Diary of a Wimpy Kid #10)', 11.83, 5, 'Humor'),
#  ('No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon',
#   21.95,
#   2,
#   'Nonfiction'),
#  ('Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#   38.39,
#   2,
#   'Sequential Art'),
#  ('My Name Is Lucy Barton', 41.56, 1, 'Fiction'),
#  ('My Mrs. Brown', 24.48, 3, 'Fiction'),
#  ('My Kind of Crazy', 40.36, 1, 'Young Adult'),
#  ('Mr. Mercedes (Bill Hodges Trilogy #1)', 28.9, 1, 'Fiction'),
#  ('More Than Music (Chasing the Dream #1)', 37.61, 2, 'Add a comment'),
#  ('Made to Stick: Why Some Ideas Survive and Others Die',
#   38.85,
#   5,
#   'Business'),
#  ('Luis Paints the World', 53.95, 3, 'Childrens'),
#  ('Luckiest Girl Alive', 49.83, 3, 'Default'),
#  ('Lowriders to the Center of the Earth (Lowriders in Space #2)',
#   51.51,
#   2,
#   'Sequential Art'),
#  ('Love Is a Mix Tape (Music #1)', 18.03, 1, 'Music'),
#  ('Looking for Lovely: Collecting the Moments that Matter',
#   29.14,
#   5,
#   'Nonfiction'),
#  ('Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#   46.91,
#   4,
#   'Default'),
#  ('Let It Out: A Journey Through Journaling', 26.79, 5, 'Nonfiction'),
#  ('Lady Midnight (The Dark Artifices #1)', 16.28, 5, 'Default'),
#  ("It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#   19.55,
#   1,
#   'Food and Drink'),
#  ('Island of Dragons (Unwanteds #7)', 29.65, 1, 'Fantasy'),
#  ("I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#   25.98,
#   4,
#   'Humor'),
#  ('I Am Pilgrim (Pilgrim #1)', 10.6, 4, 'Fiction'),
#  ('Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   14.75,
#   5,
#   'Humor'),
#  ('Hush, Hush (Hush, Hush #1)', 47.02, 3, 'Default'),
#  ('Hold Your Breath (Search and Rescue #1)', 28.82, 1, 'Romance'),
#  ('Hamilton: The Revolution', 58.79, 3, 'Nonfiction'),
#  ('Greek Mythic History', 10.23, 5, 'Default'),
#  ('God: The Most Unpleasant Character in All Fiction', 30.03, 5, 'Religion'),
#  ('Glory over Everything: Beyond The Kitchen House',
#   45.84,
#   3,
#   'Historical Fiction'),
#  ('Feathers: Displays of Brilliant Plumage', 49.05, 3, 'Art'),
#  ('Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   15.06,
#   4,
#   'Nonfiction'),
#  ('Every Last Word', 46.47, 3, 'Default'),
#  ('Eligible (The Austen Project #4)', 27.09, 3, 'Fiction'),
#  ('El Deafo', 57.62, 5, 'Sequential Art'),
#  ('Eight Hundred Grapes', 14.39, 4, 'Fiction'),
#  ('Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#   51.75,
#   5,
#   'Nonfiction'),
#  ('Eat Fat, Get Thin', 54.07, 2, 'Health'),
#  ("Don't Get Caught", 55.35, 1, 'Young Adult'),
#  ('Doctor Sleep (The Shining #2)', 40.12, 2, 'Horror'),
#  ('Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#   37.51,
#   5,
#   'Fantasy'),
#  ('Dear Mr. Knightley', 11.21, 5, 'Fiction'),
#  ('Daily Fantasy Sports', 36.58, 1, 'Default'),
#  ('Crazy Love: Overwhelmed by a Relentless God', 47.72, 2, 'Christian'),
#  ('Cometh the Hour (The Clifton Chronicles #6)', 25.01, 3, 'Fiction'),
#  ('Code Name Verity (Code Name Verity #1)', 22.13, 4, 'Add a comment'),
#  ('Clockwork Angel (The Infernal Devices #1)', 44.14, 1, 'Default'),
#  ('City of Glass (The Mortal Instruments #3)', 56.02, 4, 'Fantasy'),
#  ('City of Fallen Angels (The Mortal Instruments #4)', 11.23, 4, 'Default'),
#  ('City of Bones (The Mortal Instruments #1)', 43.28, 1, 'Default'),
#  ('City of Ashes (The Mortal Instruments #2)', 47.27, 1, 'Default'),
#  ('Cell', 20.29, 4, 'Add a comment'),
#  ('Catching Jordan (Hundred Oaks)', 50.83, 3, 'Young Adult'),
#  ('Carry On, Warrior: Thoughts on Life Unarmed', 31.85, 3, 'Default'),
#  ('Carrie', 46.23, 2, 'Default'),
#  ('Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   37.8,
#   4,
#   'Nonfiction'),
#  ('Brain on Fire: My Month of Madness', 49.32, 5, 'Nonfiction'),
#  ('Batman: Europa', 32.01, 2, 'Sequential Art'),
#  ('Barefoot Contessa Back to Basics', 28.01, 1, 'Food and Drink'),
#  ("Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   50.62,
#   5,
#   'Food and Drink'),
#  ('Balloon Animals', 17.03, 3, 'Fiction'),
#  ('Art Ops Vol. 1', 48.8, 3, 'Sequential Art'),
#  ('Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   58.14,
#   4,
#   'Young Adult'),
#  ('Angels Walking (Angels Walking #1)', 34.2, 2, 'Add a comment'),
#  ('Angels & Demons (Robert Langdon #1)', 51.48, 3, 'Default'),
#  ('All the Light We Cannot See', 29.87, 5, 'Historical'),
#  ('Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   10.9,
#   2,
#   'Sequential Art'),
#  ('Abstract City', 56.37, 5, 'Nonfiction'),
#  ('A Time of Torment (Charlie Parker #14)', 48.35, 5, 'Mystery'),
#  ('A Study in Scarlet (Sherlock Holmes #1)', 16.73, 2, 'Mystery'),
#  ('A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#   56.48,
#   2,
#   'Add a comment'),
#  ("A People's History of the United States", 40.79, 2, 'Add a comment'),
#  ('A Man Called Ove', 39.72, 1, 'Fiction'),
#  ('A Distant Mirror: The Calamitous 14th Century', 14.58, 3, 'History'),
#  ('A Brush of Wings (Angels Walking #3)', 55.51, 1, 'Add a comment'),
#  ('1491: New Revelations of the Americas Before Columbus', 21.8, 3, 'History'),
#  ('The Three Searches, Meaning, and the Story', 13.33, 3, 'Default'),
#  ('Searching for Meaning in Gailana', 38.73, 1, 'Fantasy'),
#  ('Rook', 37.86, 4, 'Add a comment'),
#  ('My Kitchen Year: 136 Recipes That Saved My Life',
#   11.53,
#   2,
#   'Food and Drink'),
#  ('13 Hours: The Inside Account of What Really Happened In Benghazi',
#   27.06,
#   1,
#   'Nonfiction'),
#  ("Will You Won't You Want Me?", 13.86, 3, 'Womens Fiction'),
#  ('Tipping Point for Planet Earth: How Close Are We to the Edge?',
#   37.55,
#   1,
#   'Science'),
#  ('The Star-Touched Queen', 32.3, 5, 'Fantasy'),
#  ('The Silent Sister (Riley MacPherson #1)', 46.29, 5, 'Fiction'),
#  ('The Midnight Watch: A Novel of the Titanic and the Californian',
#   26.2,
#   1,
#   'Add a comment'),
#  ('The Lonely City: Adventures in the Art of Being Alone',
#   33.26,
#   2,
#   'Nonfiction'),
#  ('The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   59.15,
#   4,
#   'Add a comment'),
#  ('The Golden Condom: And Other Essays on Love Lost and Found',
#   39.43,
#   1,
#   'Psychology'),
#  ('The Epidemic (The Program 0.6)', 14.44, 5, 'Young Adult'),
#  ('The Dinner Party', 56.54, 2, 'Fiction'),
#  ('The Diary of a Young Girl', 59.9, 3, 'Nonfiction'),
#  ('The Children', 11.88, 3, 'Add a comment'),
#  ('Stars Above (The Lunar Chronicles #4.5)', 48.05, 2, 'Young Adult'),
#  ('Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   21.21,
#   3,
#   'Nonfiction'),
#  ('Raspberry Pi Electronics Projects for the Evil Genius',
#   49.67,
#   4,
#   'Default'),
#  ('Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   43.14,
#   1,
#   'Business'),
#  ('Psycho: Sanitarium (Psycho #1.5)', 36.97, 5, 'Horror'),
#  ('Poisonous (Max Revere Novels #3)', 26.8, 3, 'Mystery'),
#  ('One with You (Crossfire #5)', 15.71, 4, 'Add a comment'),
#  ('No Love Allowed (Dodge Cove #1)', 54.65, 4, 'Young Adult'),
#  ('Murder at the 42nd Street Library (Raymond Ambler #1)',
#   54.36,
#   4,
#   'Mystery'),
#  ('Most Wanted', 35.28, 3, 'Mystery'),
#  ('Love, Lies and Spies', 20.55, 2, 'Historical Fiction'),
#  ('How to Speak Golf: An Illustrated Guide to Links Lingo',
#   58.32,
#   5,
#   'Default'),
#  ('Hide Away (Eve Duncan #20)', 11.84, 1, 'Mystery'),
#  ('Furiously Happy: A Funny Book About Horrible Things',
#   41.46,
#   4,
#   'Nonfiction'),
#  ('Everyday Italian: 125 Simple and Delicious Recipes',
#   20.1,
#   5,
#   'Food and Drink'),
#  ("Equal Is Unfair: America's Misguided Fight Against Income Inequality",
#   56.86,
#   1,
#   'Politics'),
#  ('Eleanor & Park', 56.51, 5, 'Default'),
#  ('Dirty (Dive Bar #1)', 40.83, 4, 'Romance'),
#  ('Can You Keep a Secret? (Fear Street Relaunch #4)', 48.64, 1, 'Horror'),
#  ('Boar Island (Anna Pigeon #19)', 59.48, 3, 'Mystery'),
#  ('A Paris Apartment', 39.01, 4, 'Historical Fiction'),
#  ('A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   38.77,
#   1,
#   'Food and Drink'),
#  ('Troublemaker: Surviving Hollywood and Scientology', 48.39, 2, 'Default'),
#  ('The Widow', 27.26, 2, 'Mystery'),
#  ('The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   11.68,
#   4,
#   'Nonfiction'),
#  ('The Improbability of Love', 59.45, 1, 'Fiction'),
#  ('The Art of Startup Fundraising', 21, 3, 'Business'),
#  ('Take Me Home Tonight (Rock Star Romance #3)', 53.98, 3, 'Romance'),
#  ('Sleeping Giants (Themis Files #1)', 48.74, 1, 'Science Fiction'),
#  ('Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   21.15,
#   2,
#   'Biography'),
#  ('Playing with Fire', 13.71, 3, 'Mystery'),
#  ('Off the Hook (Fishing for Trouble #1)', 47.67, 3, 'Romance'),
#  ('Mothering Sunday', 13.34, 2, 'Fiction'),
#  ('Mother, Can You Not?', 16.89, 5, 'Nonfiction'),
#  ('M Train', 27.18, 1, 'Autobiography'),
#  ('Lilac Girls', 17.28, 2, 'Historical Fiction'),
#  ('Lies and Other Acts of Love', 45.14, 1, 'Fiction'),
#  ('Lab Girl', 40.85, 1, 'Autobiography'),
#  ('Keep Me Posted', 20.46, 4, 'Womens Fiction'),
#  ("It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle",
#   56.27,
#   3,
#   'Psychology'),
#  ('Grey (Fifty Shades #4)', 48.49, 4, 'Womens Fiction'),
#  ('Exit, Pursued by a Bear', 51.34, 4, 'Young Adult'),
#  ('Daredevils', 16.34, 3, 'Fiction'),
#  ('Cravings: Recipes for What You Want to Eat', 20.5, 3, 'Food and Drink'),
#  ('Born for This: How to Find the Work You Were Meant to Do',
#   21.59,
#   5,
#   'Business'),
#  ('Arena', 21.36, 4, 'Science Fiction'),
#  ('Adultery', 20.88, 5, 'Default'),
#  ("A Mother's Reckoning: Living in the Aftermath of Tragedy",
#   19.53,
#   3,
#   'Nonfiction'),
#  ("A Gentleman's Position (Society of Gentlemen #3)", 14.75, 5, 'Romance'),
#  ('11/22/63', 48.48, 3, 'Fiction'),
#  ('10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
#   24.57,
#   2,
#   'Nonfiction'),
#  ('10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#   49.71,
#   5,
#   'Health'),
#  ('Without Shame', 48.27, 5, 'Add a comment'),
#  ('Watchmen', 58.05, 4, 'Add a comment'),
#  ('Unlimited Intuition Now', 58.87, 4, 'Default'),
#  ('Underlying Notes', 11.82, 2, 'Default'),
#  ('The Shack', 28.03, 1, 'Fiction'),
#  ('The New Brand You: Your New Image Makes the Sale for You',
#   44.05,
#   5,
#   'Default'),
#  ('The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   12.34,
#   4,
#   'Food and Drink'),
#  ('The Flowers Lied', 16.68, 2, 'Default'),
#  ('The Fabric of the Cosmos: Space, Time, and the Texture of Reality',
#   55.91,
#   1,
#   'Science'),
#  ('The Book of Mormon', 24.57, 3, 'Religion'),
#  ('The Art and Science of Low Carbohydrate Living', 52.98, 5, 'Health'),
#  ('The Alien Club', 54.4, 1, 'Young Adult'),
#  ('Suzie Snowflake: One beautiful flake (a self-esteem story)',
#   54.81,
#   5,
#   'Novels'),
#  ('Nap-a-Roo', 25.08, 1, 'Childrens'),
#  ('NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   10.41,
#   4,
#   'Default'),
#  ('Modern Day Fables', 47.44, 2, 'Default'),
#  ("If I Gave You God's Phone Number....: Searching for Spirituality in America",
#   20.91,
#   1,
#   'Spirituality'),
#  ('Fruits Basket, Vol. 9 (Fruits Basket #9)', 33.95, 4, 'Sequential Art'),
#  ('Dress Your Family in Corduroy and Denim', 43.68, 3, 'Humor'),
#  ("Don't Forget Steven", 33.23, 1, 'Young Adult'),
#  ("Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster",
#   35.92,
#   2,
#   'Nonfiction'),
#  ('Art and Fear: Observations on the Perils (and Rewards) of Artmaking',
#   48.63,
#   4,
#   'Art'),
#  ('A Shard of Ice (The Black Symphony Saga #1)', 56.63, 3, 'Fantasy'),
#  ("A Hero's Curse (The Unseen Chronicles #1)", 50.49, 3, 'Add a comment'),
#  ('23 Degrees South: A Tropical Tale of Changing Whether...',
#   35.79,
#   2,
#   'Add a comment'),
#  ('Zero to One: Notes on Startups, or How to Build the Future',
#   34.06,
#   3,
#   'Nonfiction'),
#  ('Why Not Me?', 17.76, 1, 'Nonfiction'),
#  ('When Breath Becomes Air', 39.36, 2, 'Nonfiction'),
#  ('Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   36.94,
#   2,
#   'Travel'),
#  ('The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)',
#   43.62,
#   5,
#   'Default'),
#  ('The New Drawing on the Right Side of the Brain', 43.02, 3, 'Art'),
#  ("The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#   28.45,
#   4,
#   'Nonfiction'),
#  ('The Martian (The Martian #1)', 41.39, 2, 'Default'),
#  ('The High Mountains of Portugal', 51.15, 1, 'Fiction'),
#  ('The Grownup', 35.88, 1, 'Short Stories'),
#  ("The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#   36.91,
#   1,
#   'Business'),
#  ('South of Sunshine', 28.93, 1, 'Young Adult'),
#  ('Smarter Faster Better: The Secrets of Being Productive in Life and Business',
#   38.89,
#   5,
#   'Nonfiction'),
#  ('Silence in the Dark (Logan Point #4)', 58.33, 3, 'Suspense'),
#  ('Shadows of the Past (Logan Point #1)', 39.67, 5, 'Christian Fiction'),
#  ('Roller Girl', 14.1, 5, 'Sequential Art'),
#  ('Rising Strong', 21.82, 3, 'Nonfiction'),
#  ('Proofs of God: Classical Arguments from Tertullian to Barth',
#   54.21,
#   1,
#   'Philosophy'),
#  ('Please Kill Me: The Uncensored Oral History of Punk', 31.19, 4, 'Music'),
#  ('Out of Print: City Lights Spotlight No. 14', 53.64, 5, 'Poetry'),
#  ('My Life Next Door (My Life Next Door )', 36.39, 5, 'Young Adult'),
#  ("Miller's Valley", 58.54, 2, 'Fiction'),
#  ("Man's Search for Meaning", 29.48, 3, 'Nonfiction'),
#  ("Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations",
#   25.06,
#   2,
#   'Nonfiction'),
#  ('Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',
#   12.55,
#   3,
#   'Nonfiction'),
#  ('Les Fleurs du Mal', 29.04, 5, 'Poetry'),
#  ('Left Behind (Left Behind #1)', 40.72, 2, 'Default'),
#  ("Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   45.05,
#   5,
#   'Music'),
#  ('Kierkegaard: A Christian Missionary to Christians', 47.13, 1, 'Philosophy'),
#  ('John Vassos: Industrial Design for Modern Life', 20.22, 4, 'Default'),
#  ("I'll Give You the Sun", 56.48, 1, 'Default'),
#  ('I Will Find You', 44.21, 1, 'Nonfiction'),
#  ('Hystopia: A Novel', 21.96, 4, 'Fiction'),
#  ('Howl and Other Poems', 40.45, 2, 'Poetry'),
#  ('History of Beauty', 10.29, 4, 'Art'),
#  ("Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back",
#   52.86,
#   2,
#   'Default'),
#  ('Future Shock (Future Shock #1)', 55.65, 5, 'Young Adult'),
#  ("Ender's Game (The Ender Quintet #1)", 43.64, 1, 'Default'),
#  ('Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World',
#   28.41,
#   1,
#   'Science'),
#  ('Death by Leisure: A Cautionary Tale', 37.51, 4, 'Default'),
#  ('Brilliant Beacons: A History of the American Lighthouse',
#   11.45,
#   3,
#   'History'),
#  ("Brazen: The Courage to Find the You That's Been Hiding",
#   19.22,
#   2,
#   'Nonfiction'),
#  ('Between the World and Me', 56.91, 4, 'Nonfiction'),
#  ('Being Mortal: Medicine and What Matters in the End',
#   55.06,
#   4,
#   'Nonfiction'),
#  ('A Murder Over a Girl: Justice, Gender, Junior High', 13.2, 3, 'Nonfiction'),
#  ('32 Yolks', 53.63, 2, 'Food and Drink'),
#  ('"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#   44.48,
#   5,
#   'History'),
#  ('You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#   12.08,
#   3,
#   'Self Help'),
#  ('Wildlife of New York: A Five-Borough Coloring Book', 22.14, 2, 'Default'),
#  ('What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   25.37,
#   5,
#   'Mystery'),
#  ('Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#   46.33,
#   2,
#   'Spirituality'),
#  ('Under the Tuscan Sun', 37.33, 3, 'Travel'),
#  ("Toddlers Are A**holes: It's Not Your Fault", 25.55, 1, 'Humor'),
#  ("The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible",
#   34.72,
#   1,
#   'Default'),
#  ('The Whale', 35.96, 4, 'Childrens'),
#  ('The Story of Art', 41.14, 4, 'Art'),
#  ('The Origin of Species', 10.01, 4, 'Science'),
#  ('The Great Gatsby', 36.05, 4, 'Default'),
#  ('The Good Girl', 49.03, 3, 'Default'),
#  ('The Glass Castle', 16.24, 1, 'Add a comment'),
#  ("The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#   39.55,
#   1,
#   'Biography'),
#  ('The Drowning Girls', 35.67, 3, 'Add a comment'),
#  ('The Constant Princess (The Tudor Court #1)',
#   16.62,
#   3,
#   'Historical Fiction'),
#  ('The Bourne Identity (Jason Bourne #1)', 42.78, 4, 'Fiction'),
#  ("The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   52.3,
#   5,
#   'Mystery'),
#  ('The Art Book', 32.34, 2, 'Art'),
#  ('The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#   33.17,
#   4,
#   'Default'),
#  ('Team of Rivals: The Political Genius of Abraham Lincoln',
#   20.12,
#   5,
#   'Add a comment'),
#  ('Steal Like an Artist: 10 Things Nobody Told You About Being Creative',
#   20.9,
#   2,
#   'Default'),
#  ('Sit, Stay, Love', 20.9, 3, 'Romance'),
#  ('Sister Dear', 40.2, 4, 'Fiction'),
#  ('Shrunken Treasures: Literary Classics, Short, Sweet, and Silly',
#   52.87,
#   3,
#   'Childrens'),
#  ('Rich Dad, Poor Dad', 51.74, 1, 'Business'),
#  ('Raymie Nightingale', 34.41, 2, 'Childrens'),
#  ('Playing from the Heart', 32.38, 1, 'Childrens'),
#  ('Nightstruck: A Novel', 50.35, 4, 'Young Adult'),
#  ('Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   11.38,
#   5,
#   'Food and Drink'),
#  ('Meternity', 43.58, 3, 'Womens Fiction'),
#  ('Memoirs of a Geisha', 49.67, 3, 'Fiction'),
#  ('Like Never Before (Walker Family #2)', 28.77, 2, 'Christian Fiction'),
#  ('Life of Pi', 13.22, 4, 'Default'),
#  ('Leave This Song Behind: Teen Poetry at Its Best', 51.17, 5, 'Poetry'),
#  ("King's Folly (The Kinsman Chronicles #1)", 39.61, 5, 'Fantasy'),
#  ('John Adams', 57.43, 4, 'Add a comment'),
#  ('How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#   46.01,
#   4,
#   'Food and Drink'),
#  ('How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#   28.25,
#   2,
#   'Food and Drink'),
#  ('Good in Bed (Cannie Shapiro #1)', 37.05, 5, 'Add a comment'),
#  ('Fruits Basket, Vol. 7 (Fruits Basket #7)', 19.57, 1, 'Sequential Art'),
#  ('For the Love: Fighting for Grace in a World of Impossible Standards',
#   45.13,
#   3,
#   'Nonfiction'),
#  ('Finding God in the Ruins: How God Redeems Pain', 46.64, 2, 'Nonfiction'),
#  ('Every Heart a Doorway (Every Heart A Doorway #1)', 12.16, 5, 'Fantasy'),
#  ('Delivering the Truth (Quaker Midwife Mystery #1)', 20.89, 4, 'Mystery'),
#  ('Counted With the Stars (Out from Egypt #1)', 17.97, 5, 'Christian Fiction'),
#  ('Chronicles, Vol. 1', 52.6, 2, 'Music'),
#  ('Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#   25.77,
#   1,
#   'Christian'),
#  ('Benjamin Franklin: An American Life', 48.19, 3, 'Biography'),
#  ('At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#   29.93,
#   5,
#   'Philosophy'),
#  ('A Summer In Europe', 44.34, 2, 'Travel'),
#  ('A Short History of Nearly Everything', 52.4, 5, 'History'),
#  ('A Gathering of Shadows (Shades of Magic #2)', 44.81, 4, 'Fantasy'),
#  ('The Sound Of Love', 57.84, 5, 'Default'),
#  ('The Rise and Fall of the Third Reich: A History of Nazi Germany',
#   39.67,
#   2,
#   'History'),
#  ('The Perks of Being a Wallflower', 55.02, 3, 'Default'),
#  ('The Mysterious Affair at Styles (Hercule Poirot #1)', 24.8, 4, 'Mystery'),
#  ('The Man Who Mistook His Wife for a Hat and Other Clinical Tales',
#   59.45,
#   4,
#   'Nonfiction'),
#  ('The Makings of a Fatherless Child', 31.58, 2, 'Default'),
#  ('The Joy of Cooking', 43.27, 4, 'Add a comment'),
#  ('The Invention of Wings', 37.34, 1, 'Historical Fiction'),
#  ('The Hobbit (Middle-Earth Universe)', 17.8, 5, 'Default'),
#  ('The Great Railway Bazaar', 30.54, 1, 'Travel'),
#  ('The Golden Compass (His Dark Materials #1)', 18.77, 1, 'Add a comment'),
#  ('The God Delusion', 46.85, 3, 'Add a comment'),
#  ('The Girl You Left Behind (The Girl You Left Behind #1)',
#   15.79,
#   1,
#   'Historical'),
#  ('The Fellowship of the Ring (The Lord of the Rings #1)',
#   10.27,
#   2,
#   'Default'),
#  ('The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#   15.42,
#   5,
#   'Poetry'),
#  ('The Barefoot Contessa Cookbook', 59.92, 5, 'Food and Drink'),
#  ("Tell the Wolves I'm Home", 50.96, 2, 'Young Adult'),
#  ('Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',
#   30.6,
#   3,
#   'Default'),
#  ('Pride and Prejudice', 19.27, 4, 'Add a comment'),
#  ('Musicophilia: Tales of Music and the Brain', 46.58, 1, 'Default'),
#  ('Mere Christianity', 48.51, 3, 'Add a comment'),
#  ('Me Before You (Me Before You #1)', 19.02, 1, 'Fiction'),
#  ('In the Woods (Dublin Murder Squad #1)', 38.38, 2, 'Mystery'),
#  ('In Cold Blood', 49.98, 4, 'Nonfiction'),
#  ('How to Stop Worrying and Start Living', 46.49, 5, 'Self Help'),
#  ('Give It Back', 18.32, 2, 'Thriller'),
#  ('Girl, Interrupted', 42.14, 3, 'Nonfiction'),
#  ('Fun Home: A Family Tragicomic', 56.59, 4, 'Add a comment'),
#  ('Fruits Basket, Vol. 6 (Fruits Basket #6)', 20.96, 4, 'Sequential Art'),
#  ('Deception Point', 40.32, 4, 'Fiction'),
#  ('Death Note, Vol. 6: Give-and-Take (Death Note #6)',
#   36.39,
#   3,
#   'Sequential Art'),
#  ('Catherine the Great: Portrait of a Woman', 58.55, 4, 'History'),
#  ('Better Homes and Gardens New Cook Book', 39.61, 3, 'Food and Drink'),
#  ('An Unquiet Mind: A Memoir of Moods and Madness', 21.3, 3, 'Psychology'),
#  ('A Year in Provence (Provence #1)', 56.88, 4, 'Travel'),
#  ('World Without End (The Pillars of the Earth #2)',
#   32.97,
#   4,
#   'Historical Fiction'),
#  ('Will Grayson, Will Grayson (Will Grayson, Will Grayson)',
#   47.31,
#   4,
#   'Young Adult'),
#  ('Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis',
#   48.67,
#   2,
#   'Nonfiction'),
#  ('Where She Went (If I Stay #2)', 41.73, 4, 'Young Adult'),
#  ('What If?: Serious Scientific Answers to Absurd Hypothetical Questions',
#   53.68,
#   4,
#   'Default'),
#  ('Two Summers', 14.64, 1, 'Young Adult'),
#  ('This Is Your Brain on Music: The Science of a Human Obsession',
#   38.4,
#   1,
#   'Music'),
#  ('The Secret Garden', 15.08, 4, 'Classics'),
#  ('The Raven King (The Raven Cycle #4)', 30.57, 2, 'Add a comment'),
#  ('The Raven Boys (The Raven Cycle #1)', 57.74, 4, 'Fantasy'),
#  ('The Power Greens Cookbook: 140 Delicious Superfood Recipes',
#   11.05,
#   5,
#   'Food and Drink'),
#  ('The Metamorphosis', 28.58, 1, 'Classics'),
#  ("The Mathews Men: Seven Brothers and the War Against Hitler's U-boats",
#   42.91,
#   5,
#   'History'),
#  ('The Little Paris Bookshop', 24.73, 3, 'Fiction'),
#  ('The Hiding Place', 55.91, 4, 'History'),
#  ('The Grand Design', 13.76, 3, 'Science'),
#  ('The Firm', 45.56, 3, 'Fiction'),
#  ('The Fault in Our Stars', 47.22, 1, 'Default'),
#  ('The False Prince (The Ascendance Trilogy #1)', 56, 5, 'Fantasy'),
#  ('The Expatriates', 44.58, 2, 'Fiction'),
#  ('The Dream Thieves (The Raven Cycle #2)', 34.5, 1, 'Default'),
#  ('The Darkest Corners', 11.33, 5, 'Young Adult'),
#  ('The Crossover', 38.77, 4, 'Poetry'),
#  ('The 5th Wave (The 5th Wave #1)', 11.83, 2, 'Default'),
#  ('Tell the Wind and Fire', 45.51, 3, 'Fantasy'),
#  ('Tell Me Three Things', 41.81, 1, 'Young Adult'),
#  ("Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",
#   25.15,
#   4,
#   'Nonfiction'),
#  ('Siddhartha', 34.22, 5, 'Fiction'),
#  ('Shiver (The Wolves of Mercy Falls #1)', 16.23, 5, 'Default'),
#  ('Remember Me?', 11.48, 3, 'Default'),
#  ('Red Dragon (Hannibal Lecter #1)', 23.37, 3, 'Horror'),
#  ('Peak: Secrets from the New Science of Expertise', 16.28, 2, 'Science'),
#  ('My Mother Was Nuts', 31.63, 4, 'Nonfiction'),
#  ('Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',
#   24.91,
#   5,
#   'Food and Drink'),
#  ('Maybe Something Beautiful: How Art Transformed a Neighborhood',
#   22.54,
#   1,
#   'Childrens'),
#  ('Lola and the Boy Next Door (Anna and the French Kiss #2)',
#   23.63,
#   4,
#   'Young Adult'),
#  ('Logan Kade (Fallen Crest High #5.5)', 13.12, 2, 'Academic'),
#  ('Last One Home (New Beginnings #1)', 59.98, 3, 'Fiction'),
#  ('Killing Floor (Jack Reacher #1)', 31.49, 4, 'Thriller'),
#  ('Kill the Boy Band', 15.52, 5, 'Young Adult'),
#  ('Isla and the Happily Ever After (Anna and the French Kiss #3)',
#   48.13,
#   5,
#   'Young Adult'),
#  ('If I Stay (If I Stay #1)', 38.13, 5, 'Default'),
#  ("I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1)",
#   36.55,
#   2,
#   'Default'),
#  ('Harry Potter and the Deathly Hallows (Harry Potter #7)',
#   23.32,
#   1,
#   'Default'),
#  ('Fruits Basket, Vol. 5 (Fruits Basket #5)', 16.33, 1, 'Sequential Art'),
#  ('Foundation (Foundation (Publication Order) #1)',
#   32.42,
#   1,
#   'Science Fiction'),
#  ('Fool Me Once', 16.96, 1, 'Default'),
#  ('Find Her (Detective D.D. Warren #8)', 22.37, 1, 'Add a comment'),
#  ('Evicted: Poverty and Profit in the American City',
#   42.27,
#   1,
#   'Add a comment'),
#  ('Drama', 38.7, 2, 'Default'),
#  ('Dracula the Un-Dead', 35.63, 5, 'Horror'),
#  ('Digital Fortress', 58, 5, 'Fiction'),
#  ('Death Note, Vol. 5: Whiteout (Death Note #5)', 52.41, 1, 'Sequential Art'),
#  ('Data, A Love Story: How I Gamed Online Dating to Meet My Match',
#   32.35,
#   3,
#   'Nonfiction'),
#  ('Critique of Pure Reason', 20.75, 1, 'Philosophy'),
#  ('Booked', 17.49, 5, 'Poetry'),
#  ('Blue Lily, Lily Blue (The Raven Cycle #3)', 34.13, 5, 'Default'),
#  ('Approval Junkie: Adventures in Caring Too Much', 58.81, 5, 'Autobiography'),
#  ('An Abundance of Katherines', 10, 5, 'Young Adult'),
#  ("America's War for the Greater Middle East: A Military History",
#   51.22,
#   2,
#   'History'),
#  ('Alight (The Generations Trilogy #2)', 58.59, 4, 'Default'),
#  ("A Girl's Guide to Moving On (New Beginnings #2)", 31.3, 1, 'Romance'),
#  ('A Game of Thrones (A Song of Ice and Fire #1)', 46.42, 2, 'Add a comment'),
#  ('A Feast for Crows (A Song of Ice and Fire #4)', 17.21, 4, 'Fantasy'),
#  ('A Clash of Kings (A Song of Ice and Fire #2)', 10.79, 3, 'Add a comment'),
#  ('Vogue Colors A to Z: A Fashion Coloring Book', 52.35, 4, 'Default'),
#  ('The Shining (The Shining #1)', 27.88, 3, 'Default'),
#  ("The Pilgrim's Progress", 50.26, 2, 'Classics'),
#  ('The Perfect Play (Play by Play #1)', 59.99, 3, 'Romance'),
#  ('The Passion of Dolssa', 28.32, 5, 'Historical Fiction'),
#  ('The Jazz of Physics: The Secret Link Between Music and the Structure of the Universe',
#   38.71,
#   3,
#   'Nonfiction'),
#  ('The Hunger Games (The Hunger Games #1)', 29.85, 5, 'Default'),
#  ('The Hound of the Baskervilles (Sherlock Holmes #5)', 14.82, 2, 'Classics'),
#  ('The Gunning of America: Business and the Making of American Gun Culture',
#   16.81,
#   4,
#   'Nonfiction'),
#  ("The Geography of Bliss: One Grump's Search for the Happiest Places in the World",
#   28.23,
#   2,
#   'Nonfiction'),
# ...
#   57.35,
#   5,
#   'Science'),
#  ('The Devil Wears Prada (The Devil Wears Prada #1)',
#   44.29,
#   1,
#   'Womens Fiction'),
#  ('The Demon-Haunted World: Science as a Candle in the Dark',
#   52.25,
#   4,
#   'Default'),
#  ('The Day the Crayons Came Home (Crayons)', 26.33, 5, 'Childrens'),
#  ('The Da Vinci Code (Robert Langdon #2)', 22.96, 2, 'Fiction'),
#  ("The Cuckoo's Calling (Cormoran Strike #1)", 19.21, 1, 'Mystery'),
#  ('The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#   26.78,
#   4,
#   'Classics'),
#  ('The Complete Poems', 41.32, 5, 'Add a comment'),
#  ('The Catcher in the Rye', 24.55, 1, 'Add a comment'),
#  ('The Cat in the Hat (Beginner Books B-1)', 16.26, 2, 'Childrens'),
#  ('The Case for Christ (Cases for Christianity)', 47.84, 1, 'Add a comment'),
#  ('The Book Thief', 53.49, 2, 'Default'),
#  ('The Book of Basketball: The NBA According to The Sports Guy',
#   44.84,
#   5,
#   'Sports and Games'),
#  ('The Blind Side: Evolution of a Game', 53.71, 5, 'Add a comment'),
#  ('The Autobiography of Malcolm X', 23.43, 2, 'Default'),
#  ('The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution',
#   34.32,
#   3,
#   'Food and Drink'),
#  ('The Art of Fielding', 22.1, 1, 'Fiction'),
#  ("Surely You're Joking, Mr. Feynman!: Adventures of a Curious Character",
#   25.83,
#   2,
#   'Science'),
#  ('Stiff: The Curious Lives of Human Cadavers', 36.74, 3, 'Nonfiction'),
#  ('Spilled Milk: Based on a True Story', 49.51, 1, 'Nonfiction'),
#  ('Something Borrowed (Darcy & Rachel #1)', 48.96, 5, 'Womens Fiction'),
#  ('Something Blue (Darcy & Rachel #2)', 54.62, 1, 'Womens Fiction'),
#  ('Soldier (Talon #3)', 24.72, 2, 'Fantasy'),
#  ('Shopaholic & Baby (Shopaholic #5)', 46.45, 2, 'Default'),
#  ('Seven Days in the Art World', 52.33, 2, 'Add a comment'),
#  ('Seven Brief Lessons on Physics', 30.6, 4, 'Science'),
#  ('Scarlet (The Lunar Chronicles #2)', 14.57, 4, 'Young Adult'),
#  ("Sarah's Key", 46.29, 1, 'Add a comment'),
#  ('Saga, Volume 3 (Saga (Collected Editions) #3)', 21.57, 5, 'Sequential Art'),
#  ('Running with Scissors', 12.91, 4, 'Autobiography'),
#  ('Rogue Lawyer (Rogue Lawyer #1)', 50.11, 3, 'Add a comment'),
#  ('Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',
#   41.67,
#   4,
#   'Nonfiction'),
#  ('Rework', 44.88, 2, 'Business'),
#  ('Reservations for Two', 11.1, 3, 'Romance'),
#  ('Red: The True Story of Red Riding Hood', 28.54, 3, 'Childrens'),
#  ('Ready Player One', 19.07, 4, 'Science Fiction'),
#  ("Quiet: The Power of Introverts in a World That Can't Stop Talking",
#   43.55,
#   1,
#   'Default'),
#  ('Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',
#   43.63,
#   3,
#   'Sequential Art'),
#  ('Persepolis: The Story of a Childhood (Persepolis #1-2)',
#   39.13,
#   1,
#   'Sequential Art'),
#  ('Packing for Mars: The Curious Science of Life in the Void',
#   56.68,
#   2,
#   'Default'),
#  ('Outliers: The Story of Success', 14.16, 1, 'Nonfiction'),
#  ('Original Fake', 31.45, 3, 'Sequential Art'),
#  ('Orange Is the New Black', 24.61, 2, 'Default'),
#  ('One for the Money (Stephanie Plum #1)', 32.87, 2, 'Default'),
#  ('Notes from a Small Island (Notes From a Small Island #1)',
#   40.17,
#   1,
#   'Nonfiction'),
#  ('Night (The Night Trilogy #1)', 13.51, 1, 'Nonfiction'),
#  ('Neither Here nor There: Travels in Europe', 38.95, 3, 'Travel'),
#  ('Naked', 31.69, 3, 'Humor'),
#  ('Morning Star (Red Rising #3)', 29.4, 1, 'Default'),
#  ('Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing',
#   57.83,
#   1,
#   'Nonfiction'),
#  ('Midnight Riot (Peter Grant/ Rivers of London - books #1)',
#   55.46,
#   2,
#   'Fantasy'),
#  ('Me Talk Pretty One Day', 57.6, 2, 'Autobiography'),
#  ('Manuscript Found in Accra', 34.98, 2, 'Add a comment'),
#  ('Lust & Wonder', 11.87, 2, 'Autobiography'),
#  ('Lila (Gilead #3)', 12.47, 3, 'Fiction'),
#  ("Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)",
#   33.26,
#   2,
#   'Science Fiction'),
#  ('Life Without a Recipe', 59.04, 5, 'Autobiography'),
#  ('Life After Life', 26.13, 2, 'Default'),
#  ('Letter to a Christian Nation', 22.2, 1, 'Nonfiction'),
#  ("Let's Pretend This Never Happened: A Mostly True Memoir",
#   45.11,
#   1,
#   'Nonfiction'),
#  ('Legend (Legend #1)', 43.69, 4, 'Young Adult'),
#  ('Lean In: Women, Work, and the Will to Lead', 25.02, 1, 'Default'),
#  ("Lamb: The Gospel According to Biff, Christ's Childhood Pal",
#   55.5,
#   5,
#   'Humor'),
#  ('Lady Renegades (Rebel Belle #3)', 53.04, 5, 'Young Adult'),
#  ('Jurassic Park (Jurassic Park #1)', 44.97, 1, 'Fiction'),
#  ("It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond",
#   42.38,
#   1,
#   'Nonfiction'),
#  ('Is Everyone Hanging Out Without Me? (And Other Concerns)',
#   20.11,
#   3,
#   'Default'),
#  ('Into the Wild', 56.7, 5, 'Nonfiction'),
#  ('Inferno (Robert Langdon #4)', 41, 5, 'Fiction'),
#  ("In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin",
#   28.85,
#   3,
#   'Nonfiction'),
#  ('If I Run (If I Run #1)', 49.97, 4, 'Christian Fiction'),
#  ("I've Got Your Number", 19.69, 1, 'Womens Fiction'),
#  ('I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban',
#   28.88,
#   2,
#   'Nonfiction'),
#  ('Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',
#   33.14,
#   3,
#   'Food and Drink'),
#  ('House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth',
#   43.7,
#   2,
#   'History'),
#  ('House of Leaves', 54.89, 1, 'Horror'),
#  ('Horrible Bear!', 37.52, 2, 'Childrens'),
#  ('Holidays on Ice', 51.07, 2, 'Humor'),
#  ('Heir to the Sky', 44.07, 4, 'Fantasy'),
#  ('Green Eggs and Ham (Beginner Books B-16)', 10.79, 4, 'Childrens'),
#  ('Grayson, Vol 3: Nemesis (Grayson #3)', 42.72, 1, 'Sequential Art'),
#  ('Gratitude', 26.66, 5, 'Nonfiction'),
#  ('Gone Girl', 37.6, 5, 'Default'),
#  ('Golden (Heart of Dread #3)', 42.21, 4, 'Young Adult'),
#  ('Girl in the Blue Coat', 46.83, 2, 'Historical Fiction'),
#  ('Fruits Basket, Vol. 3 (Fruits Basket #3)', 45.17, 2, 'Sequential Art'),
#  ('Friday Night Lights: A Town, a Team, and a Dream',
#   51.22,
#   3,
#   'Sports and Games'),
#  ('Fire Bound (Sea Haven/Sisters of the Heart #5)', 21.28, 4, 'Add a comment'),
#  ('Fifty Shades Freed (Fifty Shades #3)', 15.36, 5, 'Adult Fiction'),
#  ('Fellside', 38.62, 1, 'Default'),
#  ('Extreme Prey (Lucas Davenport #26)', 25.4, 3, 'Mystery'),
#  ('Eragon (The Inheritance Cycle #1)', 43.87, 3, 'Fantasy'),
#  ('Eclipse (Twilight #3)', 18.74, 1, 'Default'),
#  ('Dune (Dune #1)', 54.86, 1, 'Science Fiction'),
#  ('Dracula', 52.62, 3, 'Default'),
#  ('Do Androids Dream of Electric Sheep? (Blade Runner #1)',
#   51.48,
#   1,
#   'Science Fiction'),
#  ('Disrupted: My Misadventure in the Start-Up Bubble', 15.28, 5, 'Nonfiction'),
#  ('Dead Wake: The Last Crossing of the Lusitania', 39.24, 5, 'Default'),
#  ('David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#   17.81,
#   1,
#   'Default'),
#  ('Darkfever (Fever #1)', 56.02, 1, 'Fantasy'),
#  ('Dark Places', 23.9, 5, 'Default'),
#  ('Crazy Rich Asians (Crazy Rich Asians #1)', 49.13, 5, 'Fiction'),
#  ('Counting Thyme', 10.62, 1, 'Childrens'),
#  ('Cosmos', 36.17, 2, 'Add a comment'),
#  ('Civilization and Its Discontents', 59.95, 2, 'Psychology'),
#  ('Cinder (The Lunar Chronicles #1)', 26.09, 1, 'Young Adult'),
#  ("Catastrophic Happiness: Finding Joy in Childhood's Messy Years",
#   37.35,
#   2,
#   'Parenting'),
#  ('Career of Evil (Cormoran Strike #3)', 24.72, 2, 'Mystery'),
#  ('Breaking Dawn (Twilight #4)', 35.28, 5, 'Default'),
#  ('Brave Enough', 51.32, 5, 'Nonfiction'),
#  ('Boy Meets Boy', 21.12, 3, 'Young Adult'),
#  ('Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen',
#   27.35,
#   2,
#   'Nonfiction'),
#  ('Blink: The Power of Thinking Without Thinking', 21.74, 5, 'Nonfiction'),
#  ('Black Flags: The Rise of ISIS', 40.87, 1, 'Nonfiction'),
#  ('Black Butler, Vol. 1 (Black Butler #1)', 49.31, 1, 'Sequential Art'),
#  ('Big Little Lies', 22.11, 1, 'Fiction'),
#  ('Between Shades of Gray', 20.79, 5, 'Historical Fiction'),
#  ("Best of My Love (Fool's Gold #20)", 27.41, 2, 'Romance'),
#  ('Beowulf', 38.35, 2, 'Classics'),
#  ('Beautiful Creatures (Caster Chronicles #1)', 21.55, 5, 'Default'),
#  ('Awkward', 38.02, 2, 'Sequential Art'),
#  ('Ash', 22.06, 4, 'Fantasy'),
#  ('Are We There Yet?', 10.66, 3, 'Childrens'),
#  ('Are We Smart Enough to Know How Smart Animals Are?',
#   56.58,
#   1,
#   'Nonfiction'),
#  ('Annie on My Mind', 36.83, 5, 'Young Adult'),
#  ('And Then There Were None', 35.01, 2, 'Classics'),
#  ('A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#   30.48,
#   4,
#   'Nonfiction'),
#  ('A Visit from the Goon Squad', 14.08, 5, 'Default'),
#  ('A Storm of Swords (A Song of Ice and Fire #3)', 31.22, 2, 'Fantasy'),
#  ('A Heartbreaking Work of Staggering Genius', 54.29, 5, 'Autobiography'),
#  ('8 Keys to Mental Health Through Exercise', 31.04, 1, 'Psychology'),
#  ('#GIRLBOSS', 50.96, 1, 'Add a comment'),
#  ('The Suffragettes (Little Black Classics, #96)', 11.89, 2, 'Nonfiction'),
#  ('The Sense of an Ending', 31.38, 3, 'Add a comment'),
#  ("The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)",
#   54.81,
#   1,
#   'Sequential Art'),
#  ('The Course of Love', 16.78, 3, 'Fiction'),
#  ('Sugar Rush (Offensive Line #2)', 24.42, 1, 'Sports and Games'),
#  ('Saga, Volume 2 (Saga (Collected Editions) #2)', 11.75, 3, 'Sequential Art'),
#  ('Run, Spot, Run: The Ethics of Keeping Pets', 20.02, 1, 'Philosophy'),
#  ('New Moon (Twilight #2)', 12.86, 4, 'Young Adult'),
#  ('Life', 31.58, 5, 'Music'),
#  ("Kindle Paperwhite User's Guide", 34, 3, 'Nonfiction'),
#  ('H is for Hawk', 57.42, 5, 'Nonfiction'),
#  ('Girl Online On Tour (Girl Online #2)', 53.47, 1, 'Young Adult'),
#  ('Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64, 5, 'Sequential Art'),
#  ('Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#   52.88,
#   4,
#   'Childrens'),
#  ('Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#   18.51,
#   4,
#   'Sequential Art'),
#  ('While You Were Mine', 41.32, 5, 'Historical Fiction'),
#  ('Where Lightning Strikes (Bleeding Stars #3)', 39.77, 3, 'Romance'),
#  ("When I'm Gone", 51.96, 3, 'Fiction'),
#  ('Ways of Seeing', 39.51, 5, 'Art'),
#  ('Vampire Knight, Vol. 1 (Vampire Knight #1)', 15.4, 1, 'Paranormal'),
#  ('Vampire Girl (Vampire Girl #1)', 53.82, 2, 'Fantasy'),
#  ('Twenty Love Poems and a Song of Despair', 30.95, 4, 'Poetry'),
#  ('Travels with Charley: In Search of America', 57.82, 5, 'Nonfiction'),
#  ('Three Wishes (River of Time: California #1)', 44.18, 2, 'Science Fiction'),
#  ('This One Moment (Pushing Limits #1)', 48.71, 1, 'Romance'),
#  ('The Zombie Room', 19.69, 5, 'Default'),
#  ('The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#   36.52,
#   2,
#   'Sequential Art'),
#  ('The Tumor', 41.56, 5, 'Nonfiction'),
#  ('The Story of Hong Gildong', 43.19, 4, 'Classics'),
#  ('The Silent Wife', 12.34, 5, 'Fiction'),
#  ('The Silent Twin (Detective Jennifer Knight #3)', 36.25, 3, 'Fantasy'),
#  ('The Selfish Gene', 29.45, 1, 'Science'),
#  ('The Secret Healer', 34.56, 3, 'Historical Fiction'),
#  ('The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',
#   54.12,
#   3,
#   'Sequential Art'),
#  ('The Republic', 33.78, 3, 'Add a comment'),
#  ('The Odyssey', 29.64, 3, 'Add a comment'),
#  ("The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#   57.7,
#   4,
#   'Mystery'),
#  ('The Nicomachean Ethics', 36.34, 1, 'Philosophy'),
#  ('The Name of the Wind (The Kingkiller Chronicle #1)', 50.59, 3, 'Default'),
#  ('The Mirror & the Maze (The Wrath and the Dawn #1.5)', 29.38, 1, 'Fantasy'),
#  ('The Little Prince', 45.42, 2, 'Classics'),
#  ('The Light of the Fireflies', 54.43, 1, 'Add a comment'),
#  ('The Last Girl (The Dominion Trilogy #1)', 36.26, 2, 'Science Fiction'),
#  ('The Iliad', 16.16, 1, 'Add a comment'),
#  ('The Hook Up (Game On #1)', 36.29, 5, 'New Adult'),
#  ('The Haters', 27.89, 5, 'Young Adult'),
#  ('The Girl You Lost', 12.29, 5, 'Mystery'),
#  ('The Girl In The Ice (DCI Erika Foster #1)', 15.85, 3, 'Mystery'),
#  ('The End of the Jesus Era (An Investigation #1)', 14.4, 1, 'Nonfiction'),
#  ('The Edge of Reason (Bridget Jones #2)', 19.18, 4, 'Womens Fiction'),
#  ('The Complete Maus (Maus #1-2)', 10.64, 3, 'Sequential Art'),
#  ('The Communist Manifesto', 14.76, 3, 'Add a comment'),
#  ('The Bhagavad Gita', 57.49, 3, 'Religion'),
#  ('The Bette Davis Club', 30.66, 3, 'Fiction'),
#  ('The Art of Not Breathing', 40.83, 4, 'Young Adult'),
#  ('Taking Shots (Assassins #1)', 18.88, 2, 'Default'),
#  ('Starlark', 25.83, 3, 'Historical Fiction'),
#  ('Skip Beat!, Vol. 01 (Skip Beat! #1)', 42.12, 3, 'Sequential Art'),
#  ('Sister Sable (The Mad Queen #1)', 13.33, 3, 'Fantasy'),
#  ('Shatter Me (Shatter Me #1)', 42.4, 1, 'Default'),
#  ('Shameless', 58.35, 3, 'New Adult'),
#  ('Shadow Rites (Jane Yellowrock #10)', 21.72, 4, 'Fantasy'),
#  ('Settling the Score (The Summer Games #1)', 44.91, 2, 'Sports and Games'),
#  ('Sense and Sensibility', 37.46, 1, 'Classics'),
#  ('Saga, Volume 1 (Saga (Collected Editions) #1)', 28.48, 1, 'Sequential Art'),
#  ('Rhythm, Chord & Malykhin', 28.34, 2, 'Romance'),
#  ('Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   46.96,
#   5,
#   'Sequential Art'),
#  ('Paradise Lost (Paradise #1)', 24.96, 1, 'Default'),
#  ('Paper Girls, Vol. 1 (Paper Girls #1-5)', 21.71, 4, 'Sequential Art'),
#  ('Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#   29.87,
#   3,
#   'Sequential Art'),
#  ('Origins (Alphas 0.5)', 28.99, 1, 'Fantasy'),
#  ('One Second (Seven #7)', 52.94, 2, 'Fantasy'),
#  ('On the Road (Duluoz Legend)', 32.36, 3, 'Default'),
#  ("Old Records Never Die: One Man's Quest for His Vinyl and His Past",
#   55.66,
#   2,
#   'Music'),
#  ('Off Sides (Off #1)', 39.45, 5, 'New Adult'),
#  ('Of Mice and Men', 47.11, 2, 'Classics'),
#  ('Myriad (Prentor #1)', 58.75, 4, 'Fantasy'),
#  ('My Perfect Mistake (Over the Top #1)', 38.92, 2, 'Romance'),
#  ('Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   39.39,
#   4,
#   'Sequential Art'),
#  ('Meditations', 25.89, 2, 'Philosophy'),
#  ('Matilda', 28.34, 1, 'Childrens'),
#  ('Lost Among the Living', 27.7, 4, 'Historical Fiction'),
#  ('Lord of the Flies', 24.89, 3, 'Add a comment'),
#  ('Listen to Me (Fusion #1)', 58.99, 3, 'Romance'),
#  ('Kitchens of the Great Midwest', 57.2, 5, 'Fiction'),
#  ('Jane Eyre', 38.43, 5, 'Default'),
#  ('Imperfect Harmony', 34.74, 4, 'Romance'),
#  ('Icing (Aces Hockey #2)', 40.44, 4, 'Sports and Games'),
#  ('Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#   45.24,
#   3,
#   'Sequential Art'),
#  ("Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#   34.96,
#   4,
#   'Science Fiction'),
#  ('Giant Days, Vol. 1 (Giant Days #1-4)', 56.76, 4, 'Sequential Art'),
#  ('Fruits Basket, Vol. 1 (Fruits Basket #1)', 40.28, 5, 'Sequential Art'),
#  ('Frankenstein', 38, 2, 'Default'),
#  ('Forever Rockers (The Rocker #12)', 28.8, 3, 'Music'),
#  ('Fighting Fate (Fighting #6)', 39.24, 3, 'Romance'),
#  ('Emma', 32.93, 2, 'Classics'),
#  ('Eat, Pray, Love', 51.32, 3, 'Nonfiction'),
#  ('Deep Under (Walker Security #1)', 47.09, 5, 'Romance'),
#  ("Choosing Our Religion: The Spiritual Lives of America's Nones",
#   28.42,
#   4,
#   'Religion'),
#  ('Charlie and the Chocolate Factory (Charlie Bucket #1)',
#   22.85,
#   3,
#   'Childrens'),
#  ("Charity's Cross (Charles Towne Belles #4)", 41.24, 1, 'Romance'),
#  ('Bright Lines', 39.07, 5, 'Fiction'),
#  ("Bridget Jones's Diary (Bridget Jones #1)", 29.82, 1, 'Womens Fiction'),
#  ('Bounty (Colorado Mountain #7)', 37.26, 4, 'Romance'),
#  ('Blood Defense (Samantha Brinkman #1)', 20.3, 3, 'Mystery'),
#  ('Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#   34.65,
#   5,
#   'Sequential Art'),
#  ('Beyond Good and Evil', 43.38, 1, 'Philosophy'),
#  ("Alice in Wonderland (Alice's Adventures in Wonderland #1)",
#   55.53,
#   1,
#   'Classics'),
#  ('Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#   57.06,
#   4,
#   'Sequential Art'),
#  ("A Spy's Devotion (The Regency Spies of London #1)",
#   16.97,
#   5,
#   'Historical Fiction'),
#  ("1st to Die (Women's Murder Club #1)", 53.98, 1, 'Mystery'),
#  ('1,000 Places to See Before You Die', 26.08, 5, 'Travel')]

# %%
ques16 = cr.execute("SELECT sum(price) FROM book1000 where rate = 2 and price BETWEEN 10 and 40")
ques16.fetchall()[0][0]
# Out:
# [(3310.4399999999987,)]

# %%
ques17a1 = cr.execute("SELECT count(price) from book1000 WHERE rate = 1 and price BETWEEN 20 and 30")
ques17a1.fetchall()[0][0]
# Out:
# 56

# %%
ques17a2 = cr.execute("SELECT count(price) from book1000 WHERE rate = 2 and price BETWEEN 20 and 30")
ques17a2.fetchall()[0][0]
# Out:
# 40

# %%
ques17a3 = cr.execute("SELECT count(price) from book1000 WHERE rate = 3 and price BETWEEN 20 and 30")
ques17a3.fetchall() [0][0]
# Out:
# 41

# %%
ques17a4 = cr.execute("SELECT count(price) from book1000 WHERE rate = 4 and price BETWEEN 20 and 30")
ques17a4.fetchall()[0][0]
# Out:
# 34

# %%
ques17a5 = cr.execute("SELECT count(price) from book1000 WHERE rate = 5 and price BETWEEN 20 and 30")
ques17a5.fetchall()[0][0]
# Out:
# 36

# %% [markdown]
# ## Get The number of all categories

# %%
ques18 = cr.execute("SELECT category from categoriess")
g = ques18.fetchall()
a = []
for i in g:
    ques18.fetchall()
    ques17c5 = cr.execute(f"SELECT count(category) from categoriess WHERE category ='{i[0]}' ")
    print(i[0],' has ',ques17c5.fetchall()[0][0],' books')
ques18
# Out:
# Poetry  has  19  books
# Historical Fiction  has  26  books
# Fiction  has  65  books
# Mystery  has  32  books
# History  has  18  books
# Young Adult  has  54  books
# Business  has  12  books
# Default  has  152  books
# Default  has  152  books
# Poetry  has  19  books
# Default  has  152  books
# Poetry  has  19  books
# Young Adult  has  54  books
# Sequential Art  has  75  books
# Music  has  13  books
# Music  has  13  books
# Poetry  has  19  books
# Science Fiction  has  16  books
# Politics  has  3  books
# Travel  has  11  books
# Thriller  has  11  books
# Music  has  13  books
# Food and Drink  has  30  books
# Romance  has  35  books
# Romance  has  35  books
# Childrens  has  29  books
# Default  has  152  books
# Default  has  152  books
# Nonfiction  has  110  books
# Art  has  8  books
# Spirituality  has  6  books
# Nonfiction  has  110  books
# Thriller  has  11  books
# Childrens  has  29  books
# Philosophy  has  11  books
# Default  has  152  books
# Default  has  152  books
# Mystery  has  32  books
# Thriller  has  11  books
# Poetry  has  19  books
# Poetry  has  19  books
# Nonfiction  has  110  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# New Adult  has  6  books
# Contemporary  has  3  books
# Fiction  has  65  books
# Poetry  has  19  books
# Nonfiction  has  110  books
# Fantasy  has  48  books
# History  has  18  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Add a comment  has  67  books
# Childrens  has  29  books
# Food and Drink  has  30  books
# Mystery  has  32  books
# Young Adult  has  54  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Science  has  14  books
# Add a comment  has  67  books
# Nonfiction  has  110  books
# Default  has  152  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Philosophy  has  11  books
# Health  has  4  books
# Add a comment  has  67  books
# History  has  18  books
# Spirituality  has  6  books
# Nonfiction  has  110  books
# Default  has  152  books
# Horror  has  17  books
# Fantasy  has  48  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Fantasy  has  48  books
# Sequential Art  has  75  books
# History  has  18  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Self Help  has  5  books
# Add a comment  has  67  books
# Young Adult  has  54  books
# Food and Drink  has  30  books
# Fantasy  has  48  books
# Food and Drink  has  30  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Food and Drink  has  30  books
# Add a comment  has  67  books
# Science Fiction  has  16  books
# Nonfiction  has  110  books
# Science  has  14  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Self Help  has  5  books
# Romance  has  35  books
# Sequential Art  has  75  books
# Historical Fiction  has  26  books
# Romance  has  35  books
# Romance  has  35  books
# Nonfiction  has  110  books
# Religion  has  7  books
# Sequential Art  has  75  books
# Fantasy  has  48  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Young Adult  has  54  books
# Default  has  152  books
# Sequential Art  has  75  books
# Fantasy  has  48  books
# Nonfiction  has  110  books
# Default  has  152  books
# Default  has  152  books
# Mystery  has  32  books
# Historical Fiction  has  26  books
# Young Adult  has  54  books
# Fantasy  has  48  books
# Christian  has  3  books
# Religion  has  7  books
# Science Fiction  has  16  books
# Fiction  has  65  books
# Default  has  152  books
# Fantasy  has  48  books
# History  has  18  books
# Default  has  152  books
# Childrens  has  29  books
# Romance  has  35  books
# Fiction  has  65  books
# Business  has  12  books
# Philosophy  has  11  books
# Sequential Art  has  75  books
# Default  has  152  books
# Fiction  has  65  books
# Default  has  152  books
# Science Fiction  has  16  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Food and Drink  has  30  books
# Mystery  has  32  books
# New Adult  has  6  books
# New Adult  has  6  books
# Food and Drink  has  30  books
# Crime  has  1  books
# Default  has  152  books
# Historical Fiction  has  26  books
# Fantasy  has  48  books
# Default  has  152  books
# Nonfiction  has  110  books
# Default  has  152  books
# Food and Drink  has  30  books
# Default  has  152  books
# Nonfiction  has  110  books
# Default  has  152  books
# Autobiography  has  9  books
# Business  has  12  books
# Romance  has  35  books
# Romance  has  35  books
# Science Fiction  has  16  books
# Nonfiction  has  110  books
# Business  has  12  books
# Add a comment  has  67  books
# Default  has  152  books
# Young Adult  has  54  books
# Default  has  152  books
# Christian Fiction  has  6  books
# Default  has  152  books
# Poetry  has  19  books
# Young Adult  has  54  books
# Poetry  has  19  books
# Historical Fiction  has  26  books
# Add a comment  has  67  books
# Default  has  152  books
# Biography  has  5  books
# Childrens  has  29  books
# Young Adult  has  54  books
# Default  has  152  books
# Womens Fiction  has  17  books
# Fantasy  has  48  books
# Default  has  152  books
# Travel  has  11  books
# Young Adult  has  54  books
# Horror  has  17  books
# Default  has  152  books
# Fiction  has  65  books
# Sequential Art  has  75  books
# Default  has  152  books
# Default  has  152  books
# Default  has  152  books
# Romance  has  35  books
# Food and Drink  has  30  books
# Erotica  has  1  books
# Nonfiction  has  110  books
# Christian Fiction  has  6  books
# Spirituality  has  6  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Default  has  152  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Default  has  152  books
# Default  has  152  books
# Default  has  152  books
# Cultural  has  1  books
# Default  has  152  books
# Nonfiction  has  110  books
# History  has  18  books
# Thriller  has  11  books
# Sequential Art  has  75  books
# Young Adult  has  54  books
# Politics  has  3  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Childrens  has  29  books
# Default  has  152  books
# Young Adult  has  54  books
# Default  has  152  books
# Childrens  has  29  books
# Sequential Art  has  75  books
# Young Adult  has  54  books
# Nonfiction  has  110  books
# Default  has  152  books
# Add a comment  has  67  books
# Romance  has  35  books
# Fiction  has  65  books
# Fiction  has  65  books
# Fantasy  has  48  books
# Default  has  152  books
# Add a comment  has  67  books
# Default  has  152  books
# Default  has  152  books
# Historical Fiction  has  26  books
# Psychology  has  7  books
# Humor  has  10  books
# Horror  has  17  books
# Nonfiction  has  110  books
# Mystery  has  32  books
# Add a comment  has  67  books
# Fantasy  has  48  books
# Food and Drink  has  30  books
# Thriller  has  11  books
# Fiction  has  65  books
# Add a comment  has  67  books
# Young Adult  has  54  books
# Fantasy  has  48  books
# Nonfiction  has  110  books
# Thriller  has  11  books
# Mystery  has  32  books
# Mystery  has  32  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Default  has  152  books
# Science  has  14  books
# Contemporary  has  3  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Travel  has  11  books
# Poetry  has  19  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Childrens  has  29  books
# Poetry  has  19  books
# Horror  has  17  books
# Self Help  has  5  books
# Childrens  has  29  books
# Humor  has  10  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Fiction  has  65  books
# Young Adult  has  54  books
# Fiction  has  65  books
# Add a comment  has  67  books
# Business  has  12  books
# Childrens  has  29  books
# Default  has  152  books
# Sequential Art  has  75  books
# Music  has  13  books
# Nonfiction  has  110  books
# Default  has  152  books
# Nonfiction  has  110  books
# Default  has  152  books
# Food and Drink  has  30  books
# Fantasy  has  48  books
# Humor  has  10  books
# Fiction  has  65  books
# Humor  has  10  books
# Default  has  152  books
# Romance  has  35  books
# Nonfiction  has  110  books
# Default  has  152  books
# Religion  has  7  books
# Historical Fiction  has  26  books
# Art  has  8  books
# Nonfiction  has  110  books
# Default  has  152  books
# Fiction  has  65  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Health  has  4  books
# Young Adult  has  54  books
# Horror  has  17  books
# Fantasy  has  48  books
# Fiction  has  65  books
# Default  has  152  books
# Christian  has  3  books
# Fiction  has  65  books
# Add a comment  has  67  books
# Default  has  152  books
# Fantasy  has  48  books
# Default  has  152  books
# Default  has  152  books
# Default  has  152  books
# Add a comment  has  67  books
# Young Adult  has  54  books
# Default  has  152  books
# Default  has  152  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Food and Drink  has  30  books
# Food and Drink  has  30  books
# Fiction  has  65  books
# Sequential Art  has  75  books
# Young Adult  has  54  books
# Add a comment  has  67  books
# Default  has  152  books
# Historical  has  2  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Mystery  has  32  books
# Mystery  has  32  books
# Add a comment  has  67  books
# Add a comment  has  67  books
# Fiction  has  65  books
# History  has  18  books
# Add a comment  has  67  books
# History  has  18  books
# Default  has  152  books
# Fantasy  has  48  books
# Add a comment  has  67  books
# Food and Drink  has  30  books
# Nonfiction  has  110  books
# Womens Fiction  has  17  books
# Science  has  14  books
# Fantasy  has  48  books
# Fiction  has  65  books
# Add a comment  has  67  books
# Nonfiction  has  110  books
# Add a comment  has  67  books
# Psychology  has  7  books
# Young Adult  has  54  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Add a comment  has  67  books
# Young Adult  has  54  books
# Nonfiction  has  110  books
# Default  has  152  books
# Business  has  12  books
# Horror  has  17  books
# Mystery  has  32  books
# Add a comment  has  67  books
# Young Adult  has  54  books
# Mystery  has  32  books
# Mystery  has  32  books
# Historical Fiction  has  26  books
# Default  has  152  books
# Mystery  has  32  books
# Nonfiction  has  110  books
# Food and Drink  has  30  books
# Politics  has  3  books
# Default  has  152  books
# Romance  has  35  books
# Horror  has  17  books
# Mystery  has  32  books
# Historical Fiction  has  26  books
# Food and Drink  has  30  books
# Default  has  152  books
# Mystery  has  32  books
# Nonfiction  has  110  books
# Fiction  has  65  books
# Business  has  12  books
# Romance  has  35  books
# Science Fiction  has  16  books
# Biography  has  5  books
# Mystery  has  32  books
# Romance  has  35  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Autobiography  has  9  books
# Historical Fiction  has  26  books
# Fiction  has  65  books
# Autobiography  has  9  books
# Womens Fiction  has  17  books
# Psychology  has  7  books
# Womens Fiction  has  17  books
# Young Adult  has  54  books
# Fiction  has  65  books
# Food and Drink  has  30  books
# Business  has  12  books
# Science Fiction  has  16  books
# Default  has  152  books
# Nonfiction  has  110  books
# Romance  has  35  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Health  has  4  books
# Add a comment  has  67  books
# Add a comment  has  67  books
# Default  has  152  books
# Default  has  152  books
# Fiction  has  65  books
# Default  has  152  books
# Food and Drink  has  30  books
# Default  has  152  books
# Science  has  14  books
# Religion  has  7  books
# Health  has  4  books
# Young Adult  has  54  books
# Novels  has  1  books
# Childrens  has  29  books
# Default  has  152  books
# Default  has  152  books
# Spirituality  has  6  books
# Sequential Art  has  75  books
# Humor  has  10  books
# Young Adult  has  54  books
# Nonfiction  has  110  books
# Art  has  8  books
# Fantasy  has  48  books
# Add a comment  has  67  books
# Add a comment  has  67  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Travel  has  11  books
# Default  has  152  books
# Art  has  8  books
# Nonfiction  has  110  books
# Default  has  152  books
# Fiction  has  65  books
# Short Stories  has  1  books
# Business  has  12  books
# Young Adult  has  54  books
# Nonfiction  has  110  books
# Suspense  has  1  books
# Christian Fiction  has  6  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Philosophy  has  11  books
# Music  has  13  books
# Poetry  has  19  books
# Young Adult  has  54  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Poetry  has  19  books
# Default  has  152  books
# Music  has  13  books
# Philosophy  has  11  books
# Default  has  152  books
# Default  has  152  books
# Nonfiction  has  110  books
# Fiction  has  65  books
# Poetry  has  19  books
# Art  has  8  books
# Default  has  152  books
# Young Adult  has  54  books
# Default  has  152  books
# Science  has  14  books
# Default  has  152  books
# History  has  18  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Food and Drink  has  30  books
# History  has  18  books
# Self Help  has  5  books
# Default  has  152  books
# Mystery  has  32  books
# Spirituality  has  6  books
# Travel  has  11  books
# Humor  has  10  books
# Default  has  152  books
# Childrens  has  29  books
# Art  has  8  books
# Science  has  14  books
# Default  has  152  books
# Default  has  152  books
# Add a comment  has  67  books
# Biography  has  5  books
# Add a comment  has  67  books
# Historical Fiction  has  26  books
# Fiction  has  65  books
# Mystery  has  32  books
# Art  has  8  books
# Default  has  152  books
# Add a comment  has  67  books
# Default  has  152  books
# Romance  has  35  books
# Fiction  has  65  books
# Childrens  has  29  books
# Business  has  12  books
# Childrens  has  29  books
# Childrens  has  29  books
# Young Adult  has  54  books
# Food and Drink  has  30  books
# Womens Fiction  has  17  books
# Fiction  has  65  books
# Christian Fiction  has  6  books
# Default  has  152  books
# Poetry  has  19  books
# Fantasy  has  48  books
# Add a comment  has  67  books
# Food and Drink  has  30  books
# Food and Drink  has  30  books
# Add a comment  has  67  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Fantasy  has  48  books
# Mystery  has  32  books
# Christian Fiction  has  6  books
# Music  has  13  books
# Christian  has  3  books
# Biography  has  5  books
# Philosophy  has  11  books
# Travel  has  11  books
# History  has  18  books
# Fantasy  has  48  books
# Default  has  152  books
# History  has  18  books
# Default  has  152  books
# Mystery  has  32  books
# Nonfiction  has  110  books
# Default  has  152  books
# Add a comment  has  67  books
# Historical Fiction  has  26  books
# Default  has  152  books
# Travel  has  11  books
# Add a comment  has  67  books
# Add a comment  has  67  books
# Historical  has  2  books
# Default  has  152  books
# Poetry  has  19  books
# Food and Drink  has  30  books
# Young Adult  has  54  books
# Default  has  152  books
# Add a comment  has  67  books
# Default  has  152  books
# Add a comment  has  67  books
# Fiction  has  65  books
# Mystery  has  32  books
# Nonfiction  has  110  books
# Self Help  has  5  books
# Thriller  has  11  books
# Nonfiction  has  110  books
# Add a comment  has  67  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Sequential Art  has  75  books
# History  has  18  books
# Food and Drink  has  30  books
# Psychology  has  7  books
# Travel  has  11  books
# Historical Fiction  has  26  books
# Young Adult  has  54  books
# Nonfiction  has  110  books
# Young Adult  has  54  books
# Default  has  152  books
# Young Adult  has  54  books
# Music  has  13  books
# Classics  has  19  books
# Add a comment  has  67  books
# Fantasy  has  48  books
# Food and Drink  has  30  books
# Classics  has  19  books
# History  has  18  books
# Fiction  has  65  books
# History  has  18  books
# Science  has  14  books
# Fiction  has  65  books
# Default  has  152  books
# Fantasy  has  48  books
# Fiction  has  65  books
# Default  has  152  books
# Young Adult  has  54  books
# Poetry  has  19  books
# Default  has  152  books
# Fantasy  has  48  books
# Young Adult  has  54  books
# Nonfiction  has  110  books
# Fiction  has  65  books
# Default  has  152  books
# Default  has  152  books
# Horror  has  17  books
# Science  has  14  books
# Nonfiction  has  110  books
# Food and Drink  has  30  books
# Childrens  has  29  books
# Young Adult  has  54  books
# Academic  has  1  books
# Fiction  has  65  books
# Thriller  has  11  books
# Young Adult  has  54  books
# Young Adult  has  54  books
# Default  has  152  books
# Default  has  152  books
# Default  has  152  books
# Sequential Art  has  75  books
# Science Fiction  has  16  books
# Default  has  152  books
# Add a comment  has  67  books
# Add a comment  has  67  books
# Default  has  152  books
# Horror  has  17  books
# Fiction  has  65  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Philosophy  has  11  books
# Poetry  has  19  books
# Default  has  152  books
# Autobiography  has  9  books
# Young Adult  has  54  books
# History  has  18  books
# Default  has  152  books
# Romance  has  35  books
# Add a comment  has  67  books
# Fantasy  has  48  books
# Add a comment  has  67  books
# Default  has  152  books
# Default  has  152  books
# Classics  has  19  books
# Romance  has  35  books
# Historical Fiction  has  26  books
# Nonfiction  has  110  books
# Default  has  152  books
# Classics  has  19  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Fantasy  has  48  books
# Sequential Art  has  75  books
# Thriller  has  11  books
# Fantasy  has  48  books
# Womens Fiction  has  17  books
# Womens Fiction  has  17  books
# Fantasy  has  48  books
# Default  has  152  books
# Music  has  13  books
# Music  has  13  books
# Horror  has  17  books
# Horror  has  17  books
# Default  has  152  books
# Horror  has  17  books
# Classics  has  19  books
# Horror  has  17  books
# Default  has  152  books
# Young Adult  has  54  books
# Fantasy  has  48  books
# Fantasy  has  48  books
# Fantasy  has  48  books
# Classics  has  19  books
# Nonfiction  has  110  books
# Historical Fiction  has  26  books
# Sequential Art  has  75  books
# Thriller  has  11  books
# Romance  has  35  books
# Default  has  152  books
# Romance  has  35  books
# Classics  has  19  books
# Womens Fiction  has  17  books
# Fiction  has  65  books
# Classics  has  19  books
# Romance  has  35  books
# Spirituality  has  6  books
# Religion  has  7  books
# Horror  has  17  books
# Default  has  152  books
# Classics  has  19  books
# Default  has  152  books
# Default  has  152  books
# Default  has  152  books
# Humor  has  10  books
# Nonfiction  has  110  books
# Contemporary  has  3  books
# Young Adult  has  54  books
# Historical Fiction  has  26  books
# Nonfiction  has  110  books
# Food and Drink  has  30  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Young Adult  has  54  books
# Default  has  152  books
# Womens Fiction  has  17  books
# Nonfiction  has  110  books
# Fiction  has  65  books
# Psychology  has  7  books
# Childrens  has  29  books
# Sequential Art  has  75  books
# Womens Fiction  has  17  books
# Thriller  has  11  books
# Add a comment  has  67  books
# Childrens  has  29  books
# Horror  has  17  books
# Food and Drink  has  30  books
# Mystery  has  32  books
# Sequential Art  has  75  books
# Fantasy  has  48  books
# Travel  has  11  books
# Biography  has  5  books
# Science Fiction  has  16  books
# Add a comment  has  67  books
# Historical Fiction  has  26  books
# Add a comment  has  67  books
# Romance  has  35  books
# Classics  has  19  books
# Default  has  152  books
# Romance  has  35  books
# Fiction  has  65  books
# Young Adult  has  54  books
# Womens Fiction  has  17  books
# Nonfiction  has  110  books
# Default  has  152  books
# Default  has  152  books
# Childrens  has  29  books
# Business  has  12  books
# Historical Fiction  has  26  books
# Young Adult  has  54  books
# Fiction  has  65  books
# Fiction  has  65  books
# Add a comment  has  67  books
# History  has  18  books
# Historical Fiction  has  26  books
# Default  has  152  books
# Default  has  152  books
# Horror  has  17  books
# Default  has  152  books
# Add a comment  has  67  books
# Mystery  has  32  books
# Add a comment  has  67  books
# Science  has  14  books
# Science  has  14  books
# Womens Fiction  has  17  books
# Default  has  152  books
# Childrens  has  29  books
# Fiction  has  65  books
# Mystery  has  32  books
# Classics  has  19  books
# Add a comment  has  67  books
# Add a comment  has  67  books
# Childrens  has  29  books
# Add a comment  has  67  books
# Default  has  152  books
# Sports and Games  has  5  books
# Add a comment  has  67  books
# Default  has  152  books
# Food and Drink  has  30  books
# Fiction  has  65  books
# Science  has  14  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Womens Fiction  has  17  books
# Womens Fiction  has  17  books
# Fantasy  has  48  books
# Default  has  152  books
# Add a comment  has  67  books
# Science  has  14  books
# Young Adult  has  54  books
# Add a comment  has  67  books
# Sequential Art  has  75  books
# Autobiography  has  9  books
# Add a comment  has  67  books
# Nonfiction  has  110  books
# Business  has  12  books
# Romance  has  35  books
# Childrens  has  29  books
# Science Fiction  has  16  books
# Default  has  152  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Default  has  152  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Default  has  152  books
# Default  has  152  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Travel  has  11  books
# Humor  has  10  books
# Default  has  152  books
# Nonfiction  has  110  books
# Fantasy  has  48  books
# Autobiography  has  9  books
# Add a comment  has  67  books
# Autobiography  has  9  books
# Fiction  has  65  books
# Science Fiction  has  16  books
# Autobiography  has  9  books
# Default  has  152  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Young Adult  has  54  books
# Default  has  152  books
# Humor  has  10  books
# Young Adult  has  54  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Default  has  152  books
# Nonfiction  has  110  books
# Fiction  has  65  books
# Nonfiction  has  110  books
# Christian Fiction  has  6  books
# Womens Fiction  has  17  books
# Nonfiction  has  110  books
# Food and Drink  has  30  books
# History  has  18  books
# Horror  has  17  books
# Childrens  has  29  books
# Humor  has  10  books
# Fantasy  has  48  books
# Childrens  has  29  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Default  has  152  books
# Young Adult  has  54  books
# Historical Fiction  has  26  books
# Sequential Art  has  75  books
# Sports and Games  has  5  books
# Add a comment  has  67  books
# Adult Fiction  has  1  books
# Default  has  152  books
# Mystery  has  32  books
# Fantasy  has  48  books
# Default  has  152  books
# Science Fiction  has  16  books
# Default  has  152  books
# Science Fiction  has  16  books
# Nonfiction  has  110  books
# Default  has  152  books
# Default  has  152  books
# Fantasy  has  48  books
# Default  has  152  books
# Fiction  has  65  books
# Childrens  has  29  books
# Add a comment  has  67  books
# Psychology  has  7  books
# Young Adult  has  54  books
# Parenting  has  1  books
# Mystery  has  32  books
# Default  has  152  books
# Nonfiction  has  110  books
# Young Adult  has  54  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Historical Fiction  has  26  books
# Romance  has  35  books
# Classics  has  19  books
# Default  has  152  books
# Sequential Art  has  75  books
# Fantasy  has  48  books
# Childrens  has  29  books
# Nonfiction  has  110  books
# Young Adult  has  54  books
# Classics  has  19  books
# Nonfiction  has  110  books
# Default  has  152  books
# Fantasy  has  48  books
# Autobiography  has  9  books
# Psychology  has  7  books
# Add a comment  has  67  books
# Nonfiction  has  110  books
# Add a comment  has  67  books
# Sequential Art  has  75  books
# Fiction  has  65  books
# Sports and Games  has  5  books
# Sequential Art  has  75  books
# Philosophy  has  11  books
# Young Adult  has  54  books
# Music  has  13  books
# Nonfiction  has  110  books
# Nonfiction  has  110  books
# Young Adult  has  54  books
# Sequential Art  has  75  books
# Childrens  has  29  books
# Sequential Art  has  75  books
# Historical Fiction  has  26  books
# Romance  has  35  books
# Fiction  has  65  books
# Art  has  8  books
# Paranormal  has  1  books
# Fantasy  has  48  books
# Poetry  has  19  books
# Nonfiction  has  110  books
# Science Fiction  has  16  books
# Romance  has  35  books
# Default  has  152  books
# Sequential Art  has  75  books
# Nonfiction  has  110  books
# Classics  has  19  books
# Fiction  has  65  books
# Fantasy  has  48  books
# Science  has  14  books
# Historical Fiction  has  26  books
# Sequential Art  has  75  books
# Add a comment  has  67  books
# Add a comment  has  67  books
# Mystery  has  32  books
# Philosophy  has  11  books
# Default  has  152  books
# Fantasy  has  48  books
# Classics  has  19  books
# Add a comment  has  67  books
# Science Fiction  has  16  books
# Add a comment  has  67  books
# New Adult  has  6  books
# Young Adult  has  54  books
# Mystery  has  32  books
# Mystery  has  32  books
# Nonfiction  has  110  books
# Womens Fiction  has  17  books
# Sequential Art  has  75  books
# Add a comment  has  67  books
# Religion  has  7  books
# Fiction  has  65  books
# Young Adult  has  54  books
# Default  has  152  books
# Historical Fiction  has  26  books
# Sequential Art  has  75  books
# Fantasy  has  48  books
# Default  has  152  books
# New Adult  has  6  books
# Fantasy  has  48  books
# Sports and Games  has  5  books
# Classics  has  19  books
# Sequential Art  has  75  books
# Romance  has  35  books
# Sequential Art  has  75  books
# Default  has  152  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Fantasy  has  48  books
# Fantasy  has  48  books
# Default  has  152  books
# Music  has  13  books
# New Adult  has  6  books
# Classics  has  19  books
# Fantasy  has  48  books
# Romance  has  35  books
# Sequential Art  has  75  books
# Philosophy  has  11  books
# Childrens  has  29  books
# Historical Fiction  has  26  books
# Add a comment  has  67  books
# Romance  has  35  books
# Fiction  has  65  books
# Default  has  152  books
# Romance  has  35  books
# Sports and Games  has  5  books
# Sequential Art  has  75  books
# Science Fiction  has  16  books
# Sequential Art  has  75  books
# Sequential Art  has  75  books
# Default  has  152  books
# Music  has  13  books
# Romance  has  35  books
# Classics  has  19  books
# Nonfiction  has  110  books
# Romance  has  35  books
# Religion  has  7  books
# Childrens  has  29  books
# Romance  has  35  books
# Fiction  has  65  books
# Womens Fiction  has  17  books
# Romance  has  35  books
# Mystery  has  32  books
# Sequential Art  has  75  books
# Philosophy  has  11  books
# Classics  has  19  books
# Sequential Art  has  75  books
# Historical Fiction  has  26  books
# Mystery  has  32  books
# Travel  has  11  books
# Suspens  has  1  books

# %%
ques19 = cr.execute("SELECT bookname from book1000 INNER JOIN categoriess on categoriess.bookid=book1000.bookid WHERE category = 'Music'")
ques19.fetchall()
# Out:
# [('Rip it Up and Start Again',),
#  ('Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',),
#  ('How Music Works',),
#  ('Love Is a Mix Tape (Music #1)',),
#  ('Please Kill Me: The Uncensored Oral History of Punk',),
#  ("Kill 'Em and Leave: Searching for James Brown and the American Soul",),
#  ('Chronicles, Vol. 1',),
#  ('This Is Your Brain on Music: The Science of a Human Obsession',),
#  ('Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',),
#  ('No One Here Gets Out Alive',),
#  ('Life',),
#  ("Old Records Never Die: One Man's Quest for His Vinyl and His Past",),
#  ('Forever Rockers (The Rocker #12)',)]
